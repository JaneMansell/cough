# %% [markdown]
# # **Code to download the Virufy audio files from the Virufy Github repository.**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

folder = '/content/drive/My Drive/Colab Notebooks/virufy'
if not os.path.exists(folder):
  print(folder + ' does not exist')
data_folder = '/content/drive/My Drive/Colab Notebooks/virufy/public_dataset'
if not os.path.exists(data_folder):
  print(data_folder + ' does not exist')

# %% [markdown]
# Clone virufy data from github.

# %%
# !git clone "https://github.com/virufy/virufy-cdf-india-clinical-1"
# %cd virufy-cdf-india-clinical-1
# Out:
# Cloning into 'virufy-cdf-india-clinical-1'...
# remote: Enumerating objects: 146, done.
# remote: Counting objects: 100% (146/146), done.
# remote: Compressing objects: 100% (129/129), done.
# remote: Total 146 (delta 30), reused 122 (delta 15), pack-reused 0
# Receiving objects: 100% (146/146), 13.64 MiB | 17.24 MiB/s, done.
# Resolving deltas: 100% (30/30), done.
# /content/virufy-cdf-india-clinical-1

# %%
destination_folder = data_folder
if not os.path.exists(destination_folder):
    os.makedirs(destination_folder) # Creates the folder if it doesn't exist

current_folder = '/content/virufy-cdf-india-clinical-1/virufy-cdf-india-clinical-1'
if not os.path.exists(current_folder):
    raise("Check the path for virufy dataset directory!")

# %% [markdown]
# Download the cough audio files.

# %%
import os
import shutil
filenames = os.listdir(current_folder)

for filename in filenames:
   shutil.copy(os.path.join(current_folder,filename), os.path.join(destination_folder, filename))

# %% [markdown]
# I also need the metadata which is provided in a csv file.

# %%
virufy_data_dir = '/content/virufy-cdf-india-clinical-1/'
destination_folder = '/content/drive/My Drive/Colab Notebooks/virufy'
shutil.copy(os.path.join(virufy_data_dir, 'virufy-cdf-india-clinical-1-full.csv'), os.path.join(destination_folder, 'virufy_metadata.csv'))
# Out:
# '/content/drive/My Drive/Colab Notebooks/virufy/virufy_metadata.csv'

# %% [markdown]
# Check file saved.

# %%
import pandas as pd

df_virufy = pd.read_csv(os.path.join(destination_folder, 'virufy_metadata.csv'))

df_virufy.head()
# Out:
#                          id            source  ...  respiratory_condition gender
# 0  5f5b48f12cf4d_1599817969  india-clinical-1  ...                    NaN    NaN
# 1  5f5b4915b89b4_1599818005  india-clinical-1  ...                    NaN    NaN
# 2  5f606ac23a79b_1600154306  india-clinical-1  ...                    NaN    NaN
# 3  5f606bedbb001_1600154605  india-clinical-1  ...                    NaN    NaN
# 4  5f606c6f36516_1600154735  india-clinical-1  ...                    NaN    NaN
#
# [5 rows x 11 columns]

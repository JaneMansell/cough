# %% [markdown]
# Using a dataset of mfccs with a RNN-LSTM model with oversampling.
#
# The minority class is oversampled to match the majority class.
#
# A bidirectional LSTM Layer is used.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import warnings
warnings.simplefilter("ignore")
import os
import numpy as np
import matplotlib.pyplot as plt
import math
import json
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.utils import plot_model
from contextlib import redirect_stdout
import numpy as np
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras import optimizers
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_curve

# %%
folder = '/content/drive/My Drive/Colab Notebooks/COVID-19'
if not os.path.exists(folder):
  print(folder + ' does not exist')

mfcc_folder = os.path.join(folder, 'mfcc_json_files')
if not os.path.exists(mfcc_folder):
  print(mfcc_folder + ' does not exist')

# %% [markdown]
# Read in json files created previously in Extract_rawMFCCs.ipynb.

# %%
def load_jsonfile(path, filename):
  with open(os.path.join(path, filename)) as json_file:
    data = json.load(json_file)
  print("{} loaded".format(filename))
  return data

# %%
test_data = load_jsonfile(mfcc_folder, 'test_mfccs.json')
train_data = load_jsonfile(mfcc_folder, 'train_mfccs.json')
# Out:
# test_mfccs.json loaded
# train_mfccs.json loaded

# %% [markdown]
# Change labels to 0s and 1s

# %%
test_data_labels = []
for i in range (len(test_data["labels"])):
  if test_data["labels"][i] == 'healthy':
    test_data_labels.append(1)
  else:
    test_data_labels.append(0)

train_data_labels = []
for i in range (len(train_data["labels"])):
  if train_data["labels"][i] == 'healthy':
    train_data_labels.append(1)
  else:
    train_data_labels.append(0)

# %% [markdown]
# Create X_train, y_train, X_test, y_test

# %%
# Test data
X_test = np.array(test_data["mfcc"])
y_test = np.array(test_data_labels)

# Train data
X_train = np.array(train_data["mfcc"])
y_train = np.array(train_data_labels)

print("X_train shape: {}, y_train shape: {}, X_test shape: {}, y_test shape: {}".format(
    X_train.shape, y_train.shape, X_test.shape, y_test.shape))
# Out:
# X_train shape: (11401, 301, 13), y_train shape: (11401,), X_test shape: (1000, 301, 13), y_test shape: (1000,)

# %% [markdown]
# Split out a validation set

# %%
validation_size = 0.2
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=validation_size)

# %% [markdown]
# Check shape of X_train, y_train, X_val, y_val, X_test and y_test

# %%
print(X_train.shape)
print(y_train.shape)
print(X_val.shape)
print(y_val.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (9120, 301, 13)
# (9120,)
# (2281, 301, 13)
# (2281,)
# (1000, 301, 13)
# (1000,)

# %% [markdown]
# Oversample minority class in training set only.

# %%
# How many of each class in training set.
count0 = 0
count1 = 0
for i in range (y_train.shape[0]):
  if y_train[i] == 0:
    count0 += 1
  else:
    count1 +=1
print("0: {}, 1: {}".format(count0, count1))
print()
# Out:
# 0: 939, 1: 8181

# %%
data_0 = []
label_0 = []
data_1 = []
label_1 = []

for i in range (y_train.shape[0]):
  if y_train[i] == 0:
    data_0.append(X_train[i])
    label_0.append(y_train[i])
  else:
    data_1.append(X_train[i])
    label_1.append(y_train[i])

data_new = data_0 + data_1
label_new = label_0 + label_1

for i in range (int(count1/count0)-1):
  data_new += data_0
  label_new += label_0

oversampled_X_train = np.array(data_new)
oversampled_y_train = np.array(label_new)

print(oversampled_X_train)
print(oversampled_y_train)

print(oversampled_X_train.shape)
print(oversampled_y_train.shape)
# Out:
# [[[-2.12619857e+02 -1.10666308e-14  0.00000000e+00 ...  0.00000000e+00
#     0.00000000e+00 -1.34373226e-15]
#   [-2.12619857e+02 -1.10666308e-14  0.00000000e+00 ...  0.00000000e+00
#     0.00000000e+00 -1.34373226e-15]
#   [-2.12619857e+02 -1.10666308e-14  0.00000000e+00 ...  0.00000000e+00
#     0.00000000e+00 -1.34373226e-15]
#   ...
#   [-2.12619857e+02 -1.10666308e-14  0.00000000e+00 ...  0.00000000e+00
#     0.00000000e+00 -1.34373226e-15]
#   [-2.12619857e+02 -1.10666308e-14  0.00000000e+00 ...  0.00000000e+00
#     0.00000000e+00 -1.34373226e-15]
#   [-2.12619857e+02 -1.10666308e-14  0.00000000e+00 ...  0.00000000e+00
#     0.00000000e+
0.00000000e+00 ... -1.97655197e-15
#     0.00000000e+00  0.00000000e+00]
#   [-2.13332226e+02  0.00000000e+00  0.00000000e+00 ... -1.97655197e-15
#     0.00000000e+00  0.00000000e+00]]]
# [0 0 0 ... 0 0 0]
# (15693, 301, 13)
# (15693,)

# %%
# How many of each class in  oversampled training set.
count0 = 0
count1 = 0
for i in range (oversampled_y_train.shape[0]):
  if oversampled_y_train[i] == 0:
    count0 += 1
  else:
    count1 +=1
print("0: {}, 1: {}".format(count0, count1))
print()
# Out:
# 0: 7512, 1: 8181

# %%
#Replace existing X_train and y_train
X_train = oversampled_X_train
y_train = oversampled_y_train
print(X_train.shape)
print(y_train.shape)
print(X_val.shape)
print(y_val.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (15693, 301, 13)
# (15693,)
# (2281, 301, 13)
# (2281,)
# (1000, 301, 13)
# (1000,)

# %% [markdown]
# Create datasets

# %%
train_dataset = tf.data.Dataset.from_tensor_slices((X_train, y_train))
val_dataset = tf.data.Dataset.from_tensor_slices((X_val, y_val))
test_dataset = tf.data.Dataset.from_tensor_slices((X_test, y_test))

# %%
# Make sure the training data is shuffled when fed into the model

BATCH_SIZE = 100
SHUFFLE_BUFFER_SIZE = 16000 # Needs to be bigger than number of samples in training set

train_dataset = train_dataset.shuffle(SHUFFLE_BUFFER_SIZE).batch(BATCH_SIZE)
val_dataset = val_dataset.batch(BATCH_SIZE)
test_dataset = test_dataset.batch(BATCH_SIZE)

# %% [markdown]
# # RNN-LSTM Network

# %% [markdown]
# Although there are built in measures for precision and recall, there are not the equivalent measures of specificity and negative prediction rate so I have had to create custom metrics for those.
#
# I have used example in (tf.keras.metrics.Metric | TensorFlow Core v2.7.0) for Precision
#  and changed it to calculate the metrics I need.

# %%
# Always run this code.
from keras.utils import metrics_utils
from keras.utils.generic_utils import to_list
from keras import backend
class Specificity(tf.keras.metrics.Metric):
  def __init__(self,
               thresholds=None,
               top_k=None,
               class_id=None,
               name=None,
               dtype=None):
    super(Specificity, self).__init__(name=name, dtype=dtype)
    self.init_thresholds = thresholds
    self.top_k = top_k
    self.class_id = class_id

    default_threshold = 0.5 if top_k is None else metrics_utils.NEG_INF
    self.thresholds = metrics_utils.parse_init_thresholds(
        thresholds, default_threshold=default_threshold)
    self._thresholds_distributed_evenly = (
        metrics_utils.is_evenly_distributed_thresholds(self.thresholds))
    self.true_negatives = self.add_weight(
        'true_negatives',
        shape=(len(self.thresholds),),
        initializer=tf.compat.v1.zeros_initializer)
    self.false_positives = self.add_weight(
        'false_positives',
        shape=(len(self.thresholds),),
        initializer=tf.compat.v1.zeros_initializer)

  def update_state(self, y_true, y_pred, sample_weight=None):
    """Accumulates true positive and false positive statistics.
    Args:
      y_true: The ground truth values, with the same dimensions as `y_pred`.
        Will be cast to `bool`.
      y_pred: The predicted values. Each element must be in the range `[0, 1]`.
      sample_weight: Optional weighting of each example. Defaults to 1. Can be a
        `Tensor` whose rank is either 0, or the same rank as `y_true`, and must
        be broadcastable to `y_true`.
    Returns:
      Update op.
    """
    return metrics_utils.update_confusion_matrix_variables(
        {
            metrics_utils.ConfusionMatrix.TRUE_NEGATIVES: self.true_negatives,
            metrics_utils.ConfusionMatrix.FALSE_POSITIVES: self.false_positives
        },
        y_true,
        y_pred,
        thresholds=self.thresholds,
        thresholds_distributed_evenly=self._thresholds_distributed_evenly,
        top_k=self.top_k,
        class_id=self.class_id,
        sample_weight=sample_weight)

  def result(self):
    result = tf.math.divide_no_nan(
        self.true_negatives,
        tf.math.add(self.true_negatives, self.false_positives))
    return result[0] if len(self.thresholds) == 1 else result

  def reset_state(self):
    num_thresholds = len(to_list(self.thresholds))
    backend.batch_set_value([(v, np.zeros((num_thresholds,)))
                             for v in (self.true_negatives,
                                       self.false_positives)])

  def get_config(self):
    config = {
        'thresholds': self.init_thresholds,
        'top_k': self.top_k,
        'class_id': self.class_id
    }
    base_config = super(Specificity, self).get_config()
    return dict(list(base_config.items()) + list(config.items()))

# %%
# Always run this code.
from keras.utils import metrics_utils
from keras.utils.generic_utils import to_list
from keras import backend
class NPV(tf.keras.metrics.Metric):
  def __init__(self,
               thresholds=None,
               top_k=None,
               class_id=None,
               name=None,
               dtype=None):
    super(NPV, self).__init__(name=name, dtype=dtype)
    self.init_thresholds = thresholds
    self.top_k = top_k
    self.class_id = class_id

    default_threshold = 0.5 if top_k is None else metrics_utils.NEG_INF
    self.thresholds = metrics_utils.parse_init_thresholds(
        thresholds, default_threshold=default_threshold)
    self._thresholds_distributed_evenly = (
        metrics_utils.is_evenly_distributed_thresholds(self.thresholds))
    self.true_negatives = self.add_weight(
        'true_negatives',
        shape=(len(self.thresholds),),
        initializer=tf.compat.v1.zeros_initializer)
    self.false_negatives = self.add_weight(
        'false_negatives',
        shape=(len(self.thresholds),),
        initializer=tf.compat.v1.zeros_initializer)

  def update_state(self, y_true, y_pred, sample_weight=None):
    """Accumulates true positive and false positive statistics.
    Args:
      y_true: The ground truth values, with the same dimensions as `y_pred`.
        Will be cast to `bool`.
      y_pred: The predicted values. Each element must be in the range `[0, 1]`.
      sample_weight: Optional weighting of each example. Defaults to 1. Can be a
        `Tensor` whose rank is either 0, or the same rank as `y_true`, and must
        be broadcastable to `y_true`.
    Returns:
      Update op.
    """
    return metrics_utils.update_confusion_matrix_variables(
        {
            metrics_utils.ConfusionMatrix.TRUE_NEGATIVES: self.true_negatives,
            metrics_utils.ConfusionMatrix.FALSE_NEGATIVES: self.false_negatives
        },
        y_true,
        y_pred,
        thresholds=self.thresholds,
        thresholds_distributed_evenly=self._thresholds_distributed_evenly,
        top_k=self.top_k,
        class_id=self.class_id,
        sample_weight=sample_weight)

  def result(self):
    result = tf.math.divide_no_nan(
        self.true_negatives,
        tf.math.add(self.true_negatives, self.false_negatives))
    return result[0] if len(self.thresholds) == 1 else result

  def reset_state(self):
    num_thresholds = len(to_list(self.thresholds))
    backend.batch_set_value([(v, np.zeros((num_thresholds,)))
                             for v in (self.true_negatives,
                                       self.false_negatives)])

  def get_config(self):
    config = {
        'thresholds': self.init_thresholds,
        'top_k': self.top_k,
        'class_id': self.class_id
    }
    base_config = super(NPV, self).get_config()
    return dict(list(base_config.items()) + list(config.items()))

# %% [markdown]
# # **Metrics available for use**

# %%
# Always run this cell.
precision = tf.keras.metrics.Precision(name = "precision")
recall = tf.keras.metrics.Recall(name = "recall")
specificity = Specificity(name = "specificity")
TP = tf.keras.metrics.TruePositives(name = "TP") 
FP = tf.keras.metrics.FalsePositives(name = "FP")
FN = tf.keras.metrics.FalseNegatives(name = "FN")
TN = tf.keras.metrics.TrueNegatives(name = "TN")
auc = tf.keras.metrics.AUC(name = "auc")
npv = NPV(name = "NPV")

# %% [markdown]
# # **Fit model on the training dataset**

# %%
#Run this cell to create model or use next cell to load existing model.

model_name = "Covid_Model_l4.h5" #Change name here for each new model

INPUT_SHAPE = (X_train.shape[1], X_train.shape[2])

model = keras.Sequential([              
   
    # LSTM layers
    layers.Bidirectional(layers.LSTM(64,  input_shape=INPUT_SHAPE, return_sequences=True)),
    layers.Bidirectional(layers.LSTM(64)),
    
    # Head
    layers.Dense(64, activation='relu'),
    layers.Dropout(0.3),
    layers.Dense(1, activation='sigmoid')
])

model._name= model_name[:-3]

model_plots_folder = os.path.join(folder,'model_plots')

model.build((None,X_train.shape[1], X_train.shape[2]))

# Save model summaries to a text file.
with open(os.path.join(model_plots_folder,'Model_summaries.txt'), 'a') as f:
    with redirect_stdout(f):
        model.summary()

# Save model plots to individual png files.
plot_model(
    model,
    to_file=(os.path.join(model_plots_folder, model_name[:-3] + ".png")),
    show_shapes=True,
    show_dtype=False,
    show_layer_names=True,
    rankdir="TB",
    expand_nested=False,
    dpi=96,
    layer_range=None,
    show_layer_activations=False,
)

model.summary()
plot_model(model, show_shapes=True)

es_callback = EarlyStopping(monitor = 'val_auc',
                            mode='max',
                            min_delta = 0.01,
                            patience = 10,
                            restore_best_weights = True)

model.compile(
    optimizer=tf.keras.optimizers.Adam(epsilon=0.01),
    loss='binary_crossentropy',
    metrics=[TP, FP, FN, TN, 
             npv, specificity, 
             recall, auc
             ]
)

model_folder = '/content/drive/My Drive/Colab Notebooks/models/'

history = model.fit(
    train_dataset,
    validation_data=val_dataset,
    callbacks = [es_callback],
    epochs = 30
    )

model.save(model_folder + model_name)
# Out:
# Model: "Covid_Model_l4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_8 (Bidirectio  (None, 301, 128)         39936
#  nal)
#
#  bidirectional_9 (Bidirectio  (None, 128)              98816
#  nal)
#
#  dense_8 (Dense)             (None, 64)                8256
#
#  dropout_4 (Dropout)         (None, 64)                0
#
#  dense_9 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 147,073
# Trainable params: 147,073
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 157/157 [==============================] - 24s 75ms/step - loss: 0.6870 - TP: 5240.0000 - FP: 4240.0000 - FN: 2941.0000 - TN: 3272.0000 - NPV: 0.5266 - specificity: 0.4356 - recall: 0.6405 - auc: 0.5568 - val_loss: 0.6491 - val_TP: 1598.0000 - val_FP: 136.0000 - val_FN: 469.0000 - val_TN: 78.0000 - val_NPV: 0.1426 - val_specificity: 0.3645 - val_recall: 0.7731 - val_auc: 0.6077
# Epoch 2/30
# 157/157 [==============================] - 10s 65ms/step - loss: 0.6761 - TP: 5722.0000 - FP: 4222.0000 - FN: 2459.0000 - TN: 3290.0000 - NPV: 0.5723 - specificity: 0.4380 - recall: 0.6994 - auc: 0.5959 - val_loss: 0.6225 - val_TP: 1713.0000 - val_FP: 139.0000 - val_FN: 354.0000 - val_TN: 75.0000 - val_NPV: 0.1748 - val_specificity: 0.3505 - val_recall: 0.8287 - val_auc: 0.6308
# Epoch 3/30
# 157/157 [==============================] - 10s 64ms/step - loss: 0.6624 - TP: 5765.0000 - FP: 3981.0000 - FN: 2416.0000 - TN: 3531.0000 - NPV: 0.5937 - specificity: 0.4700 - recall: 0.7047 - auc: 0.6306 - val_loss: 0.5767 - val_TP: 1825.0000 - val_FP: 162.0000 - val_FN: 242.0000 - val_TN: 52.0000 - val_NPV: 0.1769 - val_specificity: 0.2430 - val_recall: 0.8829 - val_auc: 0.6590
# Epoch 4/30
# 157/157 [==============================] - 10s 66ms/step - loss: 0.6513 - TP: 5855.0000 - FP: 3735.0000 - FN: 2326.0000 - TN: 3777.0000 - NPV: 0.6189 - specificity: 0.5028 - recall: 0.7157 - auc: 0.6563 - val_loss: 0.6562 - val_TP: 1318.0000 - val_FP: 81.0000 - val_FN: 749.0000 - val_TN: 133.0000 - val_NPV: 0.1508 - val_specificity: 0.6215 - val_recall: 0.6376 - val_auc: 0.6650
# Epoch 5/30
# 157/157 [==============================] - 10s 64ms/step - loss: 0.6412 - TP: 5838.0000 - FP: 3653.0000 - FN: 2343.0000 - TN: 3859.0000 - NPV: 0.6222 - specificity: 0.5137 - recall: 0.7136 - auc: 0.6726 - val_loss: 0.6304 - val_TP: 1398.0000 - val_FP: 94.0000 - val_FN: 669.0000 - val_TN: 120.0000 - val_NPV: 0.1521 - val_specificity: 0.5607 - val_recall: 0.6763 - val_auc: 0.6557
# Epoch 6/30
# 157/157 [==============================] - 10s 64ms/step - loss: 0.6253 - TP: 5845.0000 - FP: 3269.0000 - FN: 2336.0000 - TN: 4243.0000 - NPV: 0.6449 - specificity: 0.5648 - recall: 0.7145 - auc: 0.7020 - val_loss: 0.5174 - val_TP: 1802.0000 - val_FP: 145.0000 - val_FN: 265.0000 - val_TN: 69.0000 - val_NPV: 0.2066 - val_specificity: 0.3224 - val_recall: 0.8718 - val_auc: 0.6583
# Epoch 7/30
# 157/157 [==============================] - 10s 62ms/step - loss: 0.6106 - TP: 5949.0000 - FP: 3031.0000 - FN: 2232.0000 - TN: 4481.0000 - NPV: 0.6675 - specificity: 0.5965 - recall: 0.7272 - auc: 0.7226 - val_loss: 0.7004 - val_TP: 1144.0000 - val_FP: 64.0000 - val_FN: 923.0000 - val_TN: 150.0000 - val_NPV: 0.1398 - val_specificity: 0.7009 - val_recall: 0.5535 - val_auc: 0.6718
# Epoch 8/30
# 157/157 [==============================] - 10s 65ms/step - loss: 0.6055 - TP: 5973.0000 - FP: 3003.0000 - FN: 2208.0000 - TN: 4509.0000 - NPV: 0.6713 - specificity: 0.6002 - recall: 0.7301 - auc: 0.7289 - val_loss: 0.5782 - val_TP: 1498.0000 - val_FP: 115.0000 - val_FN: 569.0000 - val_TN: 99.0000 - val_NPV: 0.1482 - val_specificity: 0.4626 - val_recall: 0.7247 - val_auc: 0.6364
# Epoch 9/30
# 157/157 [==============================] - 10s 62ms/step - loss: 0.5877 - TP: 5963.0000 - FP: 2708.0000 - FN: 2218.0000 - TN: 4804.0000 - NPV: 0.6841 - specificity: 0.6395 - recall: 0.7289 - auc: 0.7512 - val_loss: 0.6040 - val_TP: 1432.0000 - val_FP: 100.0000 - val_FN: 635.0000 - val_TN: 114.0000 - val_NPV: 0.1522 - val_specificity: 0.5327 - val_recall: 0.6928 - val_auc: 0.6525
# Epoch 10/30
# 157/157 [==============================] - 10s 64ms/step - loss: 0.5739 - TP: 6055.0000 - FP: 2610.0000 - FN: 2126.0000 - TN: 4902.0000 - NPV: 0.6975 - specificity: 0.6526 - recall: 0.7401 - auc: 0.7673 - val_loss: 0.5864 - val_TP: 1539.0000 - val_FP: 123.0000 - val_FN: 528.0000 - val_TN: 91.0000 - val_NPV: 0.1470 - val_specificity: 0.4252 - val_recall: 0.7446 - val_auc: 0.6328
# Epoch 11/30
# 157/157 [==============================] - 10s 64ms/step - loss: 0.5548 - TP: 6111.0000 - FP: 2483.0000 - FN: 2070.0000 - TN: 5029.0000 - NPV: 0.7084 - specificity: 0.6695 - recall: 0.7470 - auc: 0.7869 - val_loss: 0.3898 - val_TP: 1942.0000 - val_FP: 177.0000 - val_FN: 125.0000 - val_TN: 37.0000 - val_NPV: 0.2284 - val_specificity: 0.1729 - val_recall: 0.9395 - val_auc: 0.6184
# Epoch 12/30
# 157/157 [==============================] - 10s 64ms/step - loss: 0.5409 - TP: 6211.0000 - FP: 2389.0000 - FN: 1970.0000 - TN: 5123.0000 - NPV: 0.7223 - specificity: 0.6820 - recall: 0.7592 - auc: 0.8000 - val_loss: 0.4737 - val_TP: 1794.0000 - val_FP: 150.0000 - val_FN: 273.0000 - val_TN: 64.0000 - val_NPV: 0.1899 - val_specificity: 0.2991 - val_recall: 0.8679 - val_auc: 0.6481
# Epoch 13/30
# 157/157 [==============================] - 10s 65ms/step - loss: 0.5391 - TP: 6172.0000 - FP: 2346.0000 - FN: 2009.0000 - TN: 5166.0000 - NPV: 0.7200 - specificity: 0.6877 - recall: 0.7544 - auc: 0.8001 - val_loss: 0.5317 - val_TP: 1653.0000 - val_FP: 134.0000 - val_FN: 414.0000 - val_TN: 80.0000 - val_NPV: 0.1619 - val_specificity: 0.3738 - val_recall: 0.7997 - val_auc: 0.6281
# Epoch 14/30
# 157/157 [==============================] - 10s 64ms/step - loss: 0.5125 - TP: 6286.0000 - FP: 2157.0000 - FN: 1895.0000 - TN: 5355.0000 - NPV: 0.7386 - specificity: 0.7129 - recall: 0.7684 - auc: 0.8246 - val_loss: 0.5344 - val_TP: 1614.0000 - val_FP: 124.0000 - val_FN: 453.0000 - val_TN: 90.0000 - val_NPV: 0.1657 - val_specificity: 0.4206 - val_recall: 0.7808 - val_auc: 0.6350
# Epoch 15/30
# 157/157 [==============================] - 10s 64ms/step - loss: 0.5029 - TP: 6282.0000 - FP: 2051.0000 - FN: 1899.0000 - TN: 5461.0000 - NPV: 0.7420 - specificity: 0.7270 - recall: 0.7679 - auc: 0.8310 - val_loss: 0.4614 - val_TP: 1806.0000 - val_FP: 158.0000 - val_FN: 261.0000 - val_TN: 56.0000 - val_NPV: 0.1767 - val_specificity: 0.2617 - val_recall: 0.8737 - val_auc: 0.6217
# Epoch 16/30
# 157/157 [==============================] - 10s 64ms/step - loss: 0.4838 - TP: 6344.0000 - FP: 1894.0000 - FN: 1837.0000 - TN: 5618.0000 - NPV: 0.7536 - specificity: 0.7479 - recall: 0.7755 - auc: 0.8458 - val_loss: 0.5241 - val_TP: 1643.0000 - val_FP: 138.0000 - val_FN: 424.0000 - val_TN: 76.0000 - val_NPV: 0.1520 - val_specificity: 0.3551 - val_recall: 0.7949 - val_auc: 0.6113
# Epoch 17/30
# 157/157 [==============================] - 10s 65ms/step - loss: 0.4712 - TP: 6315.0000 - FP: 1811.0000 - FN: 1866.0000 - TN: 5701.0000 - NPV: 0.7534 - specificity: 0.7589 - recall: 0.7719 - auc: 0.8540 - val_loss: 0.5688 - val_TP: 1550.0000 - val_FP: 123.0000 - val_FN: 517.0000 - val_TN: 91.0000 - val_NPV: 0.1497 - val_specificity: 0.4252 - val_recall: 0.7499 - val_auc: 0.6042

# %%
#Only run this cell if you want to reload model run previously.
model_folder = '/content/drive/My Drive/Colab Notebooks/models/'

custom_objects = {"NPV": NPV, "Specificity": Specificity}
with keras.utils.custom_object_scope(custom_objects):
    model = tf.keras.models.load_model(model_folder + "Covid_Model_l4.h5")

# %% [markdown]
# # **Apply model to test dataset.**

# %%
_,TP,FP,FN,TN, Spec, npv, Recall, AUC = model.evaluate(test_dataset)
print('Confusion Matrix: ', TP, FP, FN, TN)
print('Test NPV: %.4f' % npv)
print('Test Specificity: %.4f' % Spec)
print('Test Sensitivity: %.4f' % Recall)
print('Test ROC-AUC: %.4f' % AUC)
# Out:
# 10/10 [==============================] - 0s 35ms/step - loss: 0.6918 - TP: 498.0000 - FP: 54.0000 - FN: 388.0000 - TN: 60.0000 - NPV: 0.1339 - specificity: 0.5263 - recall: 0.5621 - auc: 0.6028
# Confusion Matrix:  498.0 54.0 388.0 60.0
# Test NPV: 0.5263
# Test Specificity: 0.1339
# Test Sensitivity: 0.5621
# Test ROC-AUC: 0.6028

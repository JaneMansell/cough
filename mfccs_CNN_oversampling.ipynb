# %% [markdown]
# Using a dataset of mfccs with a CNN model with oversampling.
#
# The minority class is oversampled to match the majority class.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import warnings
warnings.simplefilter("ignore")
import os
import numpy as np
import matplotlib.pyplot as plt
import math
import json
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.utils import plot_model
from contextlib import redirect_stdout
import numpy as np
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras import optimizers
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_curve

# %%
folder = '/content/drive/My Drive/Colab Notebooks/COVID-19'
if not os.path.exists(folder):
  print(folder + ' does not exist')

mfcc_folder = os.path.join(folder, 'mfcc_json_files')
if not os.path.exists(mfcc_folder):
  print(mfcc_folder + ' does not exist')

# %% [markdown]
# Read in json files created previously in Extract_rawMFCCs.ipynb.

# %%
def load_jsonfile(path, filename):
  with open(os.path.join(path, filename)) as json_file:
    data = json.load(json_file)
  print("{} loaded".format(filename))
  return data

# %%
test_data = load_jsonfile(mfcc_folder, 'test_mfccs.json')
train_data = load_jsonfile(mfcc_folder, 'train_mfccs.json')
# Out:
# test_mfccs.json loaded
# train_mfccs.json loaded

# %% [markdown]
# Change labels to 0s and 1s

# %%
test_data_labels = []
for i in range (len(test_data["labels"])):
  if test_data["labels"][i] == 'healthy':
    test_data_labels.append(1)
  else:
    test_data_labels.append(0)

train_data_labels = []
for i in range (len(train_data["labels"])):
  if train_data["labels"][i] == 'healthy':
    train_data_labels.append(1)
  else:
    train_data_labels.append(0)

# %% [markdown]
# Create X_train, y_train, X_test, y_test

# %%
# Test data
X_test = np.array(test_data["mfcc"])
y_test = np.array(test_data_labels)

# Train data
X_train = np.array(train_data["mfcc"])
y_train = np.array(train_data_labels)

print("X_train shape: {}, y_train shape: {}, X_test shape: {}, y_test shape: {}".format(
    X_train.shape, y_train.shape, X_test.shape, y_test.shape))
# Out:
# X_train shape: (11401, 301, 13), y_train shape: (11401,), X_test shape: (1000, 301, 13), y_test shape: (1000,)

# %% [markdown]
# Split out a validation set

# %%
validation_size = 0.2
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=validation_size)

# %% [markdown]
# Check shape of X_train, y_train, X_val, y_val, X_test and y_test

# %%
print(X_train.shape)
print(y_train.shape)
print(X_val.shape)
print(y_val.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (9120, 301, 13)
# (9120,)
# (2281, 301, 13)
# (2281,)
# (1000, 301, 13)
# (1000,)

# %% [markdown]
# Oversample minority class in training set only.

# %%
# How many of each class in training set.
count0 = 0
count1 = 0
for i in range (y_train.shape[0]):
  if y_train[i] == 0:
    count0 += 1
  else:
    count1 +=1
print("0: {}, 1: {}".format(count0, count1))
print()
# Out:
# 0: 936, 1: 8184

# %%
data_0 = []
label_0 = []
data_1 = []
label_1 = []

for i in range (y_train.shape[0]):
  if y_train[i] == 0:
    data_0.append(X_train[i])
    label_0.append(y_train[i])
  else:
    data_1.append(X_train[i])
    label_1.append(y_train[i])

data_new = data_0 + data_1
label_new = label_0 + label_1

for i in range (int(count1/count0)-1):
  data_new += data_0
  label_new += label_0

oversampled_X_train = np.array(data_new)
oversampled_y_train = np.array(label_new)

print(oversampled_X_train)
print(oversampled_y_train)

print(oversampled_X_train.shape)
print(oversampled_y_train.shape)
# Out:
# [[[-1.99668277e+02  1.40690711e+00  1.37605795e+00 ...  5.02560367e-01
#     3.39167824e-01  1.70829451e-01]
#   [-1.99667953e+02  1.40736275e+00  1.37650360e+00 ...  5.02723125e-01
#     3.39277667e-01  1.70884776e-01]
#   [-2.00048362e+02  8.73304980e-01  8.54156084e-01 ...  3.11952700e-01
#     2.10530566e-01  1.06038423e-01]
#   ...
#   [-1.19871228e+02  5.08426244e+01 -4.93706362e+00 ... -3.50625160e+00
#     2.66115010e+00  2.67648732e+00]
#   [-1.24422966e+02  5.19692898e+01 -3.10866991e+00 ... -1.35979564e+00
#     2.19051460e+00  1.62709077e+00]
#   [-1.26807056e+02  5.22531260e+01 -7.04382410e-01 ... -2.78713708e-01
#     2.11493501e+00  1.08440940e+00]]
#
#  [[-2.37571114e+02 -2.21332616e-14 -1.08239736e-14 ...  0.00000000e+00
#    -2.66786987e-15 -2.68746452e-15]
#   [-2.37571114e+02 -2.21332616e-14 -1.08239736e-14 ...  0.00000000e+00
#    -2.66786987e-15 -2.68746452e-15]
#   [-2.37571114e+02 -2.21332616e-14 -1.08239736e-14 ...  0.00000000e+00
#    -2.66786987e-15 -2.68746452e-15]
#   ...
#   [-9.73252264e+01  7.09603214e+01 -2.24389568e+01 ... -1.40703856e+00
#     5.35029549e+00 -8.10931961e+00]
#   [-8.70825969e+01  7.27666689e+01 -1.48006868e+01 ...  2.12514162e-01
#     1.62954848e+00 -7.70676886e+00]
#   [-8.36575912e+01  7.02793492e+01 -7.28630197e+00 ... -4.99210247e-01
#     3.26484408e-01 -6.57905366e+00]]
#
#  [[-2.21102913e+02  0.00000000e+00  5.41198678e-15 ... -1.97655197e-15
#     1.33393494e-15  0.00000000e+00]
#   [-2.21102913e+02  0.00000000e+00  5.41198678e-15 ... -1.97655197e-15
#     1.33393494e-15  0.00000000e+00]
#   [-2.21102913e+02  0.00000000e+00  5.41198678e-15 ... -1.97655197e-15
#     1.33393494e-15  0.00000000e+00]
#   ...
#   [-2.21102913e+02  0.00000000e+00  5.41198678e-15 ... -1.97655197e-15
#     1.33393494e-15  0.00000000e+00]
#   [-2.21102913e+02  0.00000000e+00  5.41198678e-15 ... -1.97655197e-15
#     1.33393494e-15  0.00000000e+00]
#   [-2.21102913e+02  0.00000000e+00  5.41198678e-15 ... -1.97655197e-15
#     1.33393494e-15  0.00000000e+00]]
#
#  ...
#
#  [[-1.99300397e+02  0.00000000e+00 -1.62359603e-14 ... -1.97655197e-15
#    -4.00180481e-15  0.00000000e+00]
#   [-1.99300397e+02  0.00000000e+00 -1.62359603e-14 ... -1.97655197e-15
#    -4.00180481e-15  0.00000000e+00]
#   [-1.99300397e+02  0.00000000e+00 -1.62359603e-14 ... -1.97655197e-15
#    -4.00180481e-15  0.00000000e+00]
#   ...
#   [-1.96653542e+02  3.64836563e+00  3.37397284e+00 ... -1.24787485e-01
#    -1.60973354e-01 -1.05210856e-01]
#   [-1.96348211e+02  4.09540768e+00  3.86411988e+00 ...  4.23554004e-01
#     2.29981601e-01  9.82704632e-02]
#   [-1.96233056e+02  4.26915814e+00  4.06882908e+00 ...  7.41027184e-01
#     4.57966154e-01  2.17416285e-01]]
#
#  [[-2.16368599e+02  1.10666308e-14 -1.08239736e-14 ... -1.97655197e-15
#    -2.66786987e-15  1.34373226e-15]
#   [-2.16368599e+02  1.10666308e-14 -1.08239736e-14 ... -1.97655197e-15
#    -2.66786987e-15  1.34373226e-15]
#   [-2.16368599e+02  1.10666308e-14 -1.08239736e-14 ... -1.97655197e-15
#    -2.66786987e-15  1.34373226e-15]
#   ...
#   [-2.16368599e+02  1.10666308e-14 -1.08239736e-14 ... -1.97655197e-15
#    -2.66786987e-15  1.34373226e-15]
#   [-2.16368599e+02  1.10666308e-14 -1.08239736e-14 ... -1.97655197e-15
#    -2.66786987e-15  1.34373226e-15]
#   [-2.16368599e+02  1.10666308e-14 -1.08239736e-14 ... -1.97655197e-15
#    -2.66786987e-15  1.34373226e-15]]
#
#  [[-1.98639473e+02  0.00000000e+00  5.41198678e-15 ...  0.00000000e+00
#     1.33393494e-15  0.00000000e+00]
#   [-1.98639473e+02  0.00000000e+00  5.41198678e-15 ...  0.00000000e+00
#     1.33393494e-15  0.00000000e+00]
#   [-1.98639473e+02  0.00000000e+00  5.41198678e-15 ...  0.00000000e+00
#     1.33393494e-15  0.00000000e+00]
#   ...
#   [-1.45721100e+02  4.75945339e+01  1.42676572e+01 ... -1.53500633e+00
#    -2.69899945e+00 -1.85158655e-01]
#   [-1.48417386e+02  4.91847712e+01  1.63258548e+01 ... -1.55974563e-01
#    -3.32003804e+00 -5.41197849e-01]
#   [-1.52802532e+02  4.75154987e+01  1.84869985e+01 ...  2.35128806e-01
#    -2.50895914e+00 -1.12387030e+00]]]
# [0 0 0 ... 0 0 0]
# (15672, 301, 13)
# (15672,)

# %%
# How many of each class in  oversampled training set.
count0 = 0
count1 = 0
for i in range (oversampled_y_train.shape[0]):
  if oversampled_y_train[i] == 0:
    count0 += 1
  else:
    count1 +=1
print("0: {}, 1: {}".format(count0, count1))
print()
# Out:
# 0: 7488, 1: 8184

# %%
#Replace existing X_train and y_train
X_train = oversampled_X_train
y_train = oversampled_y_train
print(X_train.shape)
print(y_train.shape)
print(X_val.shape)
print(y_val.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (15672, 301, 13)
# (15672,)
# (2281, 301, 13)
# (2281,)
# (1000, 301, 13)
# (1000,)

# %%
# Change to 3D ready to feed into CNN
X_train = X_train[..., np.newaxis]
X_val = X_val[..., np.newaxis]
X_test = X_test[..., np.newaxis]

# %%
print(X_train.shape)
print(y_train.shape)
print(X_val.shape)
print(y_val.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (15672, 301, 13, 1)
# (15672,)
# (2281, 301, 13, 1)
# (2281,)
# (1000, 301, 13, 1)
# (1000,)

# %% [markdown]
# Create datasets

# %%
train_dataset = tf.data.Dataset.from_tensor_slices((X_train, y_train))
val_dataset = tf.data.Dataset.from_tensor_slices((X_val, y_val))
test_dataset = tf.data.Dataset.from_tensor_slices((X_test, y_test))

# %%
# Make sure the training data is shuffled when fed into the model

BATCH_SIZE = 100
SHUFFLE_BUFFER_SIZE = 10000 # Needs to be bigger than number of samples in training set

train_dataset = train_dataset.shuffle(SHUFFLE_BUFFER_SIZE).batch(BATCH_SIZE)
val_dataset = val_dataset.batch(BATCH_SIZE)
test_dataset = test_dataset.batch(BATCH_SIZE)

# %% [markdown]
# # CNN Network

# %% [markdown]
# Although there are built in measures for precision and recall, there are not the equivalent measures of specificity and negative prediction rate so I have had to create custom metrics for those.
#
# I have used example in (tf.keras.metrics.Metric | TensorFlow Core v2.7.0) for Precision
#  and changed it to calculate the metrics I need.

# %%
# Always run this code.
from keras.utils import metrics_utils
from keras.utils.generic_utils import to_list
from keras import backend
class Specificity(tf.keras.metrics.Metric):
  def __init__(self,
               thresholds=None,
               top_k=None,
               class_id=None,
               name=None,
               dtype=None):
    super(Specificity, self).__init__(name=name, dtype=dtype)
    self.init_thresholds = thresholds
    self.top_k = top_k
    self.class_id = class_id

    default_threshold = 0.5 if top_k is None else metrics_utils.NEG_INF
    self.thresholds = metrics_utils.parse_init_thresholds(
        thresholds, default_threshold=default_threshold)
    self._thresholds_distributed_evenly = (
        metrics_utils.is_evenly_distributed_thresholds(self.thresholds))
    self.true_negatives = self.add_weight(
        'true_negatives',
        shape=(len(self.thresholds),),
        initializer=tf.compat.v1.zeros_initializer)
    self.false_positives = self.add_weight(
        'false_positives',
        shape=(len(self.thresholds),),
        initializer=tf.compat.v1.zeros_initializer)

  def update_state(self, y_true, y_pred, sample_weight=None):
    """Accumulates true positive and false positive statistics.
    Args:
      y_true: The ground truth values, with the same dimensions as `y_pred`.
        Will be cast to `bool`.
      y_pred: The predicted values. Each element must be in the range `[0, 1]`.
      sample_weight: Optional weighting of each example. Defaults to 1. Can be a
        `Tensor` whose rank is either 0, or the same rank as `y_true`, and must
        be broadcastable to `y_true`.
    Returns:
      Update op.
    """
    return metrics_utils.update_confusion_matrix_variables(
        {
            metrics_utils.ConfusionMatrix.TRUE_NEGATIVES: self.true_negatives,
            metrics_utils.ConfusionMatrix.FALSE_POSITIVES: self.false_positives
        },
        y_true,
        y_pred,
        thresholds=self.thresholds,
        thresholds_distributed_evenly=self._thresholds_distributed_evenly,
        top_k=self.top_k,
        class_id=self.class_id,
        sample_weight=sample_weight)

  def result(self):
    result = tf.math.divide_no_nan(
        self.true_negatives,
        tf.math.add(self.true_negatives, self.false_positives))
    return result[0] if len(self.thresholds) == 1 else result

  def reset_state(self):
    num_thresholds = len(to_list(self.thresholds))
    backend.batch_set_value([(v, np.zeros((num_thresholds,)))
                             for v in (self.true_negatives,
                                       self.false_positives)])

  def get_config(self):
    config = {
        'thresholds': self.init_thresholds,
        'top_k': self.top_k,
        'class_id': self.class_id
    }
    base_config = super(Specificity, self).get_config()
    return dict(list(base_config.items()) + list(config.items()))

# %%
# Always run this code.
from keras.utils import metrics_utils
from keras.utils.generic_utils import to_list
from keras import backend
class NPV(tf.keras.metrics.Metric):
  def __init__(self,
               thresholds=None,
               top_k=None,
               class_id=None,
               name=None,
               dtype=None):
    super(NPV, self).__init__(name=name, dtype=dtype)
    self.init_thresholds = thresholds
    self.top_k = top_k
    self.class_id = class_id

    default_threshold = 0.5 if top_k is None else metrics_utils.NEG_INF
    self.thresholds = metrics_utils.parse_init_thresholds(
        thresholds, default_threshold=default_threshold)
    self._thresholds_distributed_evenly = (
        metrics_utils.is_evenly_distributed_thresholds(self.thresholds))
    self.true_negatives = self.add_weight(
        'true_negatives',
        shape=(len(self.thresholds),),
        initializer=tf.compat.v1.zeros_initializer)
    self.false_negatives = self.add_weight(
        'false_negatives',
        shape=(len(self.thresholds),),
        initializer=tf.compat.v1.zeros_initializer)

  def update_state(self, y_true, y_pred, sample_weight=None):
    """Accumulates true positive and false positive statistics.
    Args:
      y_true: The ground truth values, with the same dimensions as `y_pred`.
        Will be cast to `bool`.
      y_pred: The predicted values. Each element must be in the range `[0, 1]`.
      sample_weight: Optional weighting of each example. Defaults to 1. Can be a
        `Tensor` whose rank is either 0, or the same rank as `y_true`, and must
        be broadcastable to `y_true`.
    Returns:
      Update op.
    """
    return metrics_utils.update_confusion_matrix_variables(
        {
            metrics_utils.ConfusionMatrix.TRUE_NEGATIVES: self.true_negatives,
            metrics_utils.ConfusionMatrix.FALSE_NEGATIVES: self.false_negatives
        },
        y_true,
        y_pred,
        thresholds=self.thresholds,
        thresholds_distributed_evenly=self._thresholds_distributed_evenly,
        top_k=self.top_k,
        class_id=self.class_id,
        sample_weight=sample_weight)

  def result(self):
    result = tf.math.divide_no_nan(
        self.true_negatives,
        tf.math.add(self.true_negatives, self.false_negatives))
    return result[0] if len(self.thresholds) == 1 else result

  def reset_state(self):
    num_thresholds = len(to_list(self.thresholds))
    backend.batch_set_value([(v, np.zeros((num_thresholds,)))
                             for v in (self.true_negatives,
                                       self.false_negatives)])

  def get_config(self):
    config = {
        'thresholds': self.init_thresholds,
        'top_k': self.top_k,
        'class_id': self.class_id
    }
    base_config = super(NPV, self).get_config()
    return dict(list(base_config.items()) + list(config.items()))

# %% [markdown]
# # **Metrics available for use**

# %%
# Always run this cell.
precision = tf.keras.metrics.Precision(name = "precision")
recall = tf.keras.metrics.Recall(name = "recall")
specificity = Specificity(name = "specificity")
TP = tf.keras.metrics.TruePositives(name = "TP") 
FP = tf.keras.metrics.FalsePositives(name = "FP")
FN = tf.keras.metrics.FalseNegatives(name = "FN")
TN = tf.keras.metrics.TrueNegatives(name = "TN")
auc = tf.keras.metrics.AUC(name = "auc")
npv = NPV(name = "NPV")

# %% [markdown]
# # **Fit model on the training dataset**

# %%
#Run this cell to create model or use next cell to load existing model.
model_name = "Covid_Model_m3.h5" #Change name here for each new model

INPUT_SHAPE = (X_train.shape[1], X_train.shape[2], 1)

model = keras.Sequential([              
   
    # Block One
    layers.Conv2D(filters=32, kernel_size=3, activation='relu', padding='same',
                  input_shape = INPUT_SHAPE),
    layers.MaxPool2D((3, 3), strides=(2, 2), padding='same'),
    layers.BatchNormalization(),

    # Block Two
    layers.Conv2D(filters=32, kernel_size=3, activation='relu', padding='same'),
    layers.MaxPool2D((3, 3), strides=(2, 2), padding='same'),
    layers.BatchNormalization(),

    # Block Three
    layers.Conv2D(filters=32, kernel_size=3, activation='relu', padding='same'),
    layers.MaxPool2D((3, 3), strides=(2, 2), padding='same'),
    layers.BatchNormalization(),

    # Block Four
    layers.Conv2D(filters=32, kernel_size=3, activation='relu', padding='same'),
    layers.MaxPool2D((3, 3), strides=(2, 2), padding='same'),
    layers.BatchNormalization(),

    # Block Five
    layers.Conv2D(filters=32, kernel_size=3, activation='relu', padding='same'),
    layers.MaxPool2D((3, 3), strides=(2, 2), padding='same'),
    layers.BatchNormalization(),

    # Head
    layers.Flatten(),
    layers.Dropout(0.25),
    layers.Dense(128, activation='relu'),
    layers.Dropout(0.25),
    layers.Dense(1, activation='sigmoid'),
])

model._name= model_name[:-3]

model_plots_folder = os.path.join(folder,'model_plots')

# Save model summaries to a text file.
with open(os.path.join(model_plots_folder,'Model_summaries.txt'), 'a') as f:
    with redirect_stdout(f):
        model.summary()

# Save model plots to individual png files.
plot_model(
    model,
    to_file=(os.path.join(model_plots_folder, model_name[:-3] + ".png")),
    show_shapes=True,
    show_dtype=False,
    show_layer_names=True,
    rankdir="TB",
    expand_nested=False,
    dpi=96,
    layer_range=None,
    show_layer_activations=False,
)

model.summary()
plot_model(model, show_shapes=True)

es_callback = EarlyStopping(monitor = 'val_auc',
                            mode='max',
                            min_delta = 0.01,
                            patience = 10,
                            restore_best_weights = True)

model.compile(
    optimizer=tf.keras.optimizers.Adam(epsilon=0.01),
    loss='binary_crossentropy',
    metrics=[TP, FP, FN, TN, 
             npv, specificity, 
             recall, auc
             ]
)

model_folder = '/content/drive/My Drive/Colab Notebooks/models/'

history = model.fit(
    train_dataset,
    validation_data=val_dataset,
    #callbacks = [es_callback],
    epochs = 30
    )

model.save(model_folder + model_name)
# Out:
# Model: "Covid_Model_m3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_15 (Conv2D)          (None, 301, 13, 32)       320
#
#  max_pooling2d_15 (MaxPoolin  (None, 151, 7, 32)       0
#  g2D)
#
#  batch_normalization_15 (Bat  (None, 151, 7, 32)       128
#  chNormalization)
#
#  conv2d_16 (Conv2D)          (None, 151, 7, 32)        9248
#
#  max_pooling2d_16 (MaxPoolin  (None, 76, 4, 32)        0
#  g2D)
#
#  batch_normalization_16 (Bat  (None, 76, 4, 32)        128
#  chNormalization)
#
#  conv2d_17 (Conv2D)          (None, 76, 4, 32)         9248
#
#  max_pooling2d_17 (MaxPoolin  (None, 38, 2, 32)        0
#  g2D)
#
#  batch_normalization_17 (Bat  (None, 38, 2, 32)        128
#  chNormalization)
#
#  conv2d_18 (Conv2D)          (None, 38, 2, 32)         9248
#
#  max_pooling2d_18 (MaxPoolin  (None, 19, 1, 32)        0
#  g2D)
#
#  batch_normalization_18 (Bat  (None, 19, 1, 32)        128
#  chNormalization)
#
#  conv2d_19 (Conv2D)          (None, 19, 1, 32)         9248
#
#  max_pooling2d_19 (MaxPoolin  (None, 10, 1, 32)        0
#  g2D)
#
#  batch_normalization_19 (Bat  (None, 10, 1, 32)        128
#  chNormalization)
#
#  flatten_3 (Flatten)         (None, 320)               0
#
#  dropout_6 (Dropout)         (None, 320)               0
#
#  dense_6 (Dense)             (None, 128)               41088
#
#  dropout_7 (Dropout)         (None, 128)               0
#
#  dense_7 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 79,169
# Trainable params: 78,849
# Non-trainable params: 320
# _________________________________________________________________
# Epoch 1/30
# 157/157 [==============================] - 5s 21ms/step - loss: 0.7305 - TP: 4939.0000 - FP: 3194.0000 - FN: 3245.0000 - TN: 4294.0000 - NPV: 0.5696 - specificity: 0.5735 - recall: 0.6035 - auc: 0.6157 - val_loss: 0.6877 - val_TP: 1188.0000 - val_FP: 101.0000 - val_FN: 876.0000 - val_TN: 116.0000 - val_NPV: 0.1169 - val_specificity: 0.5346 - val_recall: 0.5756 - val_auc: 0.5776
# Epoch 2/30
# 157/157 [==============================] - 2s 13ms/step - loss: 0.6442 - TP: 5408.0000 - FP: 2926.0000 - FN: 2776.0000 - TN: 4562.0000 - NPV: 0.6217 - specificity: 0.6092 - recall: 0.6608 - auc: 0.6892 - val_loss: 0.6771 - val_TP: 1184.0000 - val_FP: 79.0000 - val_FN: 880.0000 - val_TN: 138.0000 - val_NPV: 0.1356 - val_specificity: 0.6359 - val_recall: 0.5736 - val_auc: 0.6686
# Epoch 3/30
# 157/157 [==============================] - 2s 13ms/step - loss: 0.6076 - TP: 5801.0000 - FP: 2743.0000 - FN: 2383.0000 - TN: 4745.0000 - NPV: 0.6657 - specificity: 0.6337 - recall: 0.7088 - auc: 0.7325 - val_loss: 0.5988 - val_TP: 1409.0000 - val_FP: 86.0000 - val_FN: 655.0000 - val_TN: 131.0000 - val_NPV: 0.1667 - val_specificity: 0.6037 - val_recall: 0.6827 - val_auc: 0.6953
# Epoch 4/30
# 157/157 [==============================] - 2s 13ms/step - loss: 0.5895 - TP: 5860.0000 - FP: 2596.0000 - FN: 2324.0000 - TN: 4892.0000 - NPV: 0.6779 - specificity: 0.6533 - recall: 0.7160 - auc: 0.7519 - val_loss: 0.6788 - val_TP: 1187.0000 - val_FP: 70.0000 - val_FN: 877.0000 - val_TN: 147.0000 - val_NPV: 0.1436 - val_specificity: 0.6774 - val_recall: 0.5751 - val_auc: 0.6859
# Epoch 5/30
# 157/157 [==============================] - 2s 13ms/step - loss: 0.5464 - TP: 6192.0000 - FP: 2394.0000 - FN: 1992.0000 - TN: 5094.0000 - NPV: 0.7189 - specificity: 0.6803 - recall: 0.7566 - auc: 0.7937 - val_loss: 0.4600 - val_TP: 1788.0000 - val_FP: 147.0000 - val_FN: 276.0000 - val_TN: 70.0000 - val_NPV: 0.2023 - val_specificity: 0.3226 - val_recall: 0.8663 - val_auc: 0.6601
# Epoch 6/30
# 157/157 [==============================] - 2s 13ms/step - loss: 0.5189 - TP: 6314.0000 - FP: 2139.0000 - FN: 1870.0000 - TN: 5349.0000 - NPV: 0.7410 - specificity: 0.7143 - recall: 0.7715 - auc: 0.8195 - val_loss: 0.4541 - val_TP: 1733.0000 - val_FP: 156.0000 - val_FN: 331.0000 - val_TN: 61.0000 - val_NPV: 0.1556 - val_specificity: 0.2811 - val_recall: 0.8396 - val_auc: 0.6542
# Epoch 7/30
# 157/157 [==============================] - 2s 12ms/step - loss: 0.4705 - TP: 6531.0000 - FP: 1881.0000 - FN: 1653.0000 - TN: 5607.0000 - NPV: 0.7723 - specificity: 0.7488 - recall: 0.7980 - auc: 0.8567 - val_loss: 0.4138 - val_TP: 1826.0000 - val_FP: 151.0000 - val_FN: 238.0000 - val_TN: 66.0000 - val_NPV: 0.2171 - val_specificity: 0.3041 - val_recall: 0.8847 - val_auc: 0.6504
# Epoch 8/30
# 157/157 [==============================] - 2s 12ms/step - loss: 0.4396 - TP: 6591.0000 - FP: 1638.0000 - FN: 1593.0000 - TN: 5850.0000 - NPV: 0.7860 - specificity: 0.7812 - recall: 0.8054 - auc: 0.8768 - val_loss: 0.9072 - val_TP: 1051.0000 - val_FP: 59.0000 - val_FN: 1013.0000 - val_TN: 158.0000 - val_NPV: 0.1349 - val_specificity: 0.7281 - val_recall: 0.5092 - val_auc: 0.6654
# Epoch 9/30
# 157/157 [==============================] - 2s 13ms/step - loss: 0.4071 - TP: 6684.0000 - FP: 1417.0000 - FN: 1500.0000 - TN: 6071.0000 - NPV: 0.8019 - specificity: 0.8108 - recall: 0.8167 - auc: 0.8963 - val_loss: 0.9131 - val_TP: 1015.0000 - val_FP: 66.0000 - val_FN: 1049.0000 - val_TN: 151.0000 - val_NPV: 0.1258 - val_specificity: 0.6959 - val_recall: 0.4918 - val_auc: 0.6602
# Epoch 10/30
# 157/157 [==============================] - 2s 13ms/step - loss: 0.3567 - TP: 6878.0000 - FP: 1185.0000 - FN: 1306.0000 - TN: 6303.0000 - NPV: 0.8284 - specificity: 0.8417 - recall: 0.8404 - auc: 0.9211 - val_loss: 0.4587 - val_TP: 1784.0000 - val_FP: 146.0000 - val_FN: 280.0000 - val_TN: 71.0000 - val_NPV: 0.2023 - val_specificity: 0.3272 - val_recall: 0.8643 - val_auc: 0.6634
# Epoch 11/30
# 157/157 [==============================] - 2s 13ms/step - loss: 0.3124 - TP: 7073.0000 - FP: 976.0000 - FN: 1111.0000 - TN: 6512.0000 - NPV: 0.8543 - specificity: 0.8697 - recall: 0.8642 - auc: 0.9400 - val_loss: 0.4035 - val_TP: 1882.0000 - val_FP: 175.0000 - val_FN: 182.0000 - val_TN: 42.0000 - val_NPV: 0.1875 - val_specificity: 0.1935 - val_recall: 0.9118 - val_auc: 0.6490
# Epoch 12/30
# 157/157 [==============================] - 2s 13ms/step - loss: 0.2825 - TP: 7171.0000 - FP: 876.0000 - FN: 1013.0000 - TN: 6612.0000 - NPV: 0.8671 - specificity: 0.8830 - recall: 0.8762 - auc: 0.9512 - val_loss: 0.7484 - val_TP: 1406.0000 - val_FP: 96.0000 - val_FN: 658.0000 - val_TN: 121.0000 - val_NPV: 0.1553 - val_specificity: 0.5576 - val_recall: 0.6812 - val_auc: 0.6566
# Epoch 13/30
# 157/157 [==============================] - 2s 13ms/step - loss: 0.2561 - TP: 7292.0000 - FP: 770.0000 - FN: 892.0000 - TN: 6718.0000 - NPV: 0.8828 - specificity: 0.8972 - recall: 0.8910 - auc: 0.9596 - val_loss: 0.6179 - val_TP: 1580.0000 - val_FP: 129.0000 - val_FN: 484.0000 - val_TN: 88.0000 - val_NPV: 0.1538 - val_specificity: 0.4055 - val_recall: 0.7655 - val_auc: 0.6509
# Epoch 14/30
# 157/157 [==============================] - 2s 13ms/step - loss: 0.2276 - TP: 7362.0000 - FP: 634.0000 - FN: 822.0000 - TN: 6854.0000 - NPV: 0.8929 - specificity: 0.9153 - recall: 0.8996 - auc: 0.9679 - val_loss: 0.7228 - val_TP: 1532.0000 - val_FP: 121.0000 - val_FN: 532.0000 - val_TN: 96.0000 - val_NPV: 0.1529 - val_specificity: 0.4424 - val_recall: 0.7422 - val_auc: 0.6257
# Epoch 15/30
# 157/157 [==============================] - 2s 13ms/step - loss: 0.1967 - TP: 7514.0000 - FP: 531.0000 - FN: 670.0000 - TN: 6957.0000 - NPV: 0.9122 - specificity: 0.9291 - recall: 0.9181 - auc: 0.9760 - val_loss: 0.5841 - val_TP: 1864.0000 - val_FP: 169.0000 - val_FN: 200.0000 - val_TN: 48.0000 - val_NPV: 0.1935 - val_specificity: 0.2212 - val_recall: 0.9031 - val_auc: 0.6037
# Epoch 16/30
# 157/157 [==============================] - 2s 13ms/step - loss: 0.1810 - TP: 7563.0000 - FP: 494.0000 - FN: 621.0000 - TN: 6994.0000 - NPV: 0.9185 - specificity: 0.9340 - recall: 0.9241 - auc: 0.9795 - val_loss: 0.5201 - val_TP: 1915.0000 - val_FP: 176.0000 - val_FN: 149.0000 - val_TN: 41.0000 - val_NPV: 0.2158 - val_specificity: 0.1889 - val_recall: 0.9278 - val_auc: 0.6311
# Epoch 17/30
# 157/157 [==============================] - 2s 13ms/step - loss: 0.1516 - TP: 7665.0000 - FP: 412.0000 - FN: 519.0000 - TN: 7076.0000 - NPV: 0.9317 - specificity: 0.9450 - recall: 0.9366 - auc: 0.9856 - val_loss: 0.5553 - val_TP: 1886.0000 - val_FP: 180.0000 - val_FN: 178.0000 - val_TN: 37.0000 - val_NPV: 0.1721 - val_specificity: 0.1705 - val_recall: 0.9138 - val_auc: 0.6007
# Epoch 18/30
# 157/157 [==============================] - 2s 13ms/step - loss: 0.1562 - TP: 7625.0000 - FP: 407.0000 - FN: 559.0000 - TN: 7081.0000 - NPV: 0.9268 - specificity: 0.9456 - recall: 0.9317 - auc: 0.9848 - val_loss: 0.6146 - val_TP: 1926.0000 - val_FP: 184.0000 - val_FN: 138.0000 - val_TN: 33.0000 - val_NPV: 0.1930 - val_specificity: 0.1521 - val_recall: 0.9331 - val_auc: 0.5716
# Epoch 19/30
# 157/157 [==============================] - 2s 13ms/step - loss: 0.1627 - TP: 7628.0000 - FP: 450.0000 - FN: 556.0000 - TN: 7038.0000 - NPV: 0.9268 - specificity: 0.9399 - recall: 0.9321 - auc: 0.9834 - val_loss: 0.5888 - val_TP: 1999.0000 - val_FP: 185.0000 - val_FN: 65.0000 - val_TN: 32.0000 - val_NPV: 0.3299 - val_specificity: 0.1475 - val_recall: 0.9685 - val_auc: 0.6093
# Epoch 20/30
# 157/157 [==============================] - 2s 13ms/step - loss: 0.1171 - TP: 7793.0000 - FP: 292.0000 - FN: 391.0000 - TN: 7196.0000 - NPV: 0.9485 - specificity: 0.9610 - recall: 0.9522 - auc: 0.9911 - val_loss: 0.6255 - val_TP: 1929.0000 - val_FP: 172.0000 - val_FN: 135.0000 - val_TN: 45.0000 - val_NPV: 0.2500 - val_specificity: 0.2074 - val_recall: 0.9346 - val_auc: 0.6148
# Epoch 21/30
# 157/157 [==============================] - 2s 13ms/step - loss: 0.1113 - TP: 7830.0000 - FP: 274.0000 - FN: 354.0000 - TN: 7214.0000 - NPV: 0.9532 - specificity: 0.9634 - recall: 0.9567 - auc: 0.9919 - val_loss: 0.6362 - val_TP: 1810.0000 - val_FP: 162.0000 - val_FN: 254.0000 - val_TN: 55.0000 - val_NPV: 0.1780 - val_specificity: 0.2535 - val_recall: 0.8769 - val_auc: 0.6355
# Epoch 22/30
# 157/157 [==============================] - 2s 13ms/step - loss: 0.1125 - TP: 7807.0000 - FP: 272.0000 - FN: 377.0000 - TN: 7216.0000 - NPV: 0.9503 - specificity: 0.9637 - recall: 0.9539 - auc: 0.9916 - val_loss: 0.6845 - val_TP: 1719.0000 - val_FP: 145.0000 - val_FN: 345.0000 - val_TN: 72.0000 - val_NPV: 0.1727 - val_specificity: 0.3318 - val_recall: 0.8328 - val_auc: 0.6409
# Epoch 23/30
# 157/157 [==============================] - 2s 13ms/step - loss: 0.1063 - TP: 7813.0000 - FP: 280.0000 - FN: 371.0000 - TN: 7208.0000 - NPV: 0.9510 - specificity: 0.9626 - recall: 0.9547 - auc: 0.9927 - val_loss: 0.6859 - val_TP: 1837.0000 - val_FP: 163.0000 - val_FN: 227.0000 - val_TN: 54.0000 - val_NPV: 0.1922 - val_specificity: 0.2488 - val_recall: 0.8900 - val_auc: 0.6434
# Epoch 24/30
# 157/157 [==============================] - 2s 13ms/step - loss: 0.0960 - TP: 7864.0000 - FP: 235.0000 - FN: 320.0000 - TN: 7253.0000 - NPV: 0.9577 - specificity: 0.9686 - recall: 0.9609 - auc: 0.9938 - val_loss: 0.7082 - val_TP: 1848.0000 - val_FP: 160.0000 - val_FN: 216.0000 - val_TN: 57.0000 - val_NPV: 0.2088 - val_specificity: 0.2627 - val_recall: 0.8953 - val_auc: 0.6386
# Epoch 25/30
# 157/157 [==============================] - 2s 13ms/step - loss: 0.0921 - TP: 7862.0000 - FP: 251.0000 - FN: 322.0000 - TN: 7237.0000 - NPV: 0.9574 - specificity: 0.9665 - recall: 0.9607 - auc: 0.9946 - val_loss: 0.6325 - val_TP: 1845.0000 - val_FP: 158.0000 - val_FN: 219.0000 - val_TN: 59.0000 - val_NPV: 0.2122 - val_specificity: 0.2719 - val_recall: 0.8939 - val_auc: 0.6561
# Epoch 26/30
# 157/157 [==============================] - 2s 13ms/step - loss: 0.0804 - TP: 7912.0000 - FP: 214.0000 - FN: 272.0000 - TN: 7274.0000 - NPV: 0.9640 - specificity: 0.9714 - recall: 0.9668 - auc: 0.9958 - val_loss: 0.7815 - val_TP: 1986.0000 - val_FP: 192.0000 - val_FN: 78.0000 - val_TN: 25.0000 - val_NPV: 0.2427 - val_specificity: 0.1152 - val_recall: 0.9622 - val_auc: 0.5935
# Epoch 27/30
# 157/157 [==============================] - 2s 13ms/step - loss: 0.0841 - TP: 7911.0000 - FP: 219.0000 - FN: 273.0000 - TN: 7269.0000 - NPV: 0.9638 - specificity: 0.9708 - recall: 0.9666 - auc: 0.9952 - val_loss: 0.6869 - val_TP: 1930.0000 - val_FP: 175.0000 - val_FN: 134.0000 - val_TN: 42.0000 - val_NPV: 0.2386 - val_specificity: 0.1935 - val_recall: 0.9351 - val_auc: 0.6280
# Epoch 28/30
# 157/157 [==============================] - 2s 13ms/step - loss: 0.0789 - TP: 7923.0000 - FP: 209.0000 - FN: 261.0000 - TN: 7279.0000 - NPV: 0.9654 - specificity: 0.9721 - recall: 0.9681 - auc: 0.9960 - val_loss: 0.7826 - val_TP: 1924.0000 - val_FP: 175.0000 - val_FN: 140.0000 - val_TN: 42.0000 - val_NPV: 0.2308 - val_specificity: 0.1935 - val_recall: 0.9322 - val_auc: 0.6328
# Epoch 29/30
# 157/157 [==============================] - 2s 13ms/step - loss: 0.0881 - TP: 7891.0000 - FP: 230.0000 - FN: 293.0000 - TN: 7258.0000 - NPV: 0.9612 - specificity: 0.9693 - recall: 0.9642 - auc: 0.9947 - val_loss: 0.7393 - val_TP: 1902.0000 - val_FP: 171.0000 - val_FN: 162.0000 - val_TN: 46.0000 - val_NPV: 0.2212 - val_specificity: 0.2120 - val_recall: 0.9215 - val_auc: 0.6192
# Epoch 30/30
# 157/157 [==============================] - 2s 13ms/step - loss: 0.0692 - TP: 7952.0000 - FP: 166.0000 - FN: 232.0000 - TN: 7322.0000 - NPV: 0.9693 - specificity: 0.9778 - recall: 0.9717 - auc: 0.9967 - val_loss: 0.7764 - val_TP: 1878.0000 - val_FP: 173.0000 - val_FN: 186.0000 - val_TN: 44.0000 - val_NPV: 0.1913 - val_specificity: 0.2028 - val_recall: 0.9099 - val_auc: 0.6109

# %%
#Only run this cell if you want to reload model run previously.
model_folder = '/content/drive/My Drive/Colab Notebooks/models/'

custom_objects = {"NPV": NPV, "Specificity": Specificity}
with keras.utils.custom_object_scope(custom_objects):
    model = tf.keras.models.load_model(model_folder + "Covid_Model_m3.h5")

# %% [markdown]
# # **Apply model to test dataset.**

# %%
_,TP,FP,FN,TN, Spec, npv, Recall, AUC = model.evaluate(test_dataset)
print('Confusion Matrix: ', TP, FP, FN, TN)
print('Test NPV: %.4f' % npv)
print('Test Specificity: %.4f' % Spec)
print('Test Sensitivity: %.4f' % Recall)
print('Test ROC-AUC: %.4f' % AUC)
# Out:
# 10/10 [==============================] - 0s 9ms/step - loss: 0.8765 - TP: 818.0000 - FP: 91.0000 - FN: 68.0000 - TN: 23.0000 - NPV: 0.2527 - specificity: 0.2018 - recall: 0.9233 - auc: 0.6088
# Confusion Matrix:  818.0 91.0 68.0 23.0
# Test NPV: 0.2018
# Test Specificity: 0.2527
# Test Sensitivity: 0.9233
# Test ROC-AUC: 0.6088

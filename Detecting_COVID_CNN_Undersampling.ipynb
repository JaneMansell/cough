# %% [markdown]
# # Investigating the benefit of using undersampling with a basic CNN to identify COVID-19 from coughs
#
# Model reads in image files that have been created from cough audio files.
# Machine learning is applied to create a classifier. The aim of undersampling is to reduce the examples of the majority class in order to balance the dataset.

# %% [markdown]
# This Model uses ImageDataGenerator

# %% [markdown]
# Mounting the Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Upload images to pandas dataframe and visualize a few images.

# %%
# Always run this code.
import os
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.image import imread
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.utils import plot_model
from contextlib import redirect_stdout
import numpy as np
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras import optimizers
from sklearn.metrics import roc_curve

folder = '/content/drive/My Drive/Colab Notebooks/COVID-19'
if not os.path.exists(folder):
  print(folder + ' does not exist')


df_images = pd.read_csv(os.path.join(folder, 'df_train.csv'), index_col=0)

fnames = df_images.loc[:,'image_file']

plt.figure(figsize=(10,10))
for i in range(12): 
    plt.subplot(3,4,i+1)
    
    filename = fnames[i]
    if not os.path.exists(filename):
      print ('No such file:'+filename)
    
    image = imread(filename)
    plt.title(image.shape)
    plt.imshow(image)
    
plt.show()

# %%
pd.set_option('max_columns', None)
print(df_images.shape)
print(df_images.head(5))
# Out:
# (11401, 8)
#                                      id   age  gender    status  \
# 0          Zb2Inq1UVhcMnWA41GpKyRdF4z62  66.0  female   healthy
# 1  c4138919-bd2c-4e24-9fcf-582e428c7d27  37.0  female   healthy
# 2          ygiPwZYsKFetOejhxWXB6rKSHAf2  66.0    male  COVID-19
# 3  ec8ddd1e-d555-490f-9719-70a99c1c6993  29.0    male   healthy
# 4          CFkIEzwZ5PcogCElOD2K3RJQzmh1  44.0    male   healthy
#
#                                           audio_file  \
# 0  /content/drive/My Drive/Colab Notebooks/coswar...
# 1  /content/drive/My Drive/Colab Notebooks/coughv...
# 2  /content/drive/My Drive/Colab Notebooks/coswar...
# 3  /content/drive/My Drive/Colab Notebooks/coughv...
# 4  /content/drive/My Drive/Colab Notebooks/coswar...
#
#                                           image_file    source  cough_detected
# 0  /content/drive/My Drive/Colab Notebooks/coswar...   coswara             NaN
# 1  /content/drive/My Drive/Colab Notebooks/coughv...  coughvid          1.0000
# 2  /content/drive/My Drive/Colab Notebooks/coswar...   coswara             NaN
# 3  /content/drive/My Drive/Colab Notebooks/coughv...  coughvid          0.7849
# 4  /content/drive/My Drive/Colab Notebooks/coswar...   coswara             NaN

# %% [markdown]
# ## Rearrange the dataset
# Split into training set and validation set

# %%
# Always run this code.
validation_proportion = 0.3 #Change this if you want to change ratio of validation to training.

num_rows = df_images.shape[0]

df_val = df_images.iloc[:int(validation_proportion*num_rows)]
df_train = df_images.iloc[int(validation_proportion*num_rows):]

print (df_images.shape)
print (df_train.shape)
print (df_val.shape)

print (df_train.head(10))
print (df_val.head(10))

#Check we have a range of images in each set.

print(df_train.groupby('status').status.count())
print(df_val.groupby('status').status.count())
# Out:
# (11401, 8)
# (7981, 8)
# (3420, 8)
#                                         id   age  gender    status  \
# 3420  6ea0f6b7-8110-4940-b848-0635be9b5978  29.0    male   healthy
# 3421          zM5GsorprLYElGQ3uJwnU0g0Fwr1  35.0    male  COVID-19
# 3422          bx564wHvi9d0HyJTtdi0haZuU493  28.0    male  COVID-19
# 3423  07e2f7e1-8e9b-4962-8701-fbe1224de7ef  28.0    male   healthy
# 3424  aeeb58ec-cefc-4d57-b2f5-db03cf502ae4   NaN  female   healthy
# 3425  79319102-5fd0-46bd-b091-017b1c0973d1  52.0    male   healthy
# 3426  f2d5ad83-91b7-4efe-9bc9-4adf3a08cf7d  30.0    male   healthy
# 3427          KFtd9lY6jph5cl2VrZ9Nv8Jng7p1  42.0    male   healthy
# 3428  1278ade5-08ec-4993-b5f8-8b8cf522e7be  45.0    male   healthy
# 3429          E3nlERKGBPcSO2PjEDJ6GrRKiy73  47.0    male  COVID-19
#
#                                              audio_file  \
# 3420  /content/drive/My Drive/Colab Notebooks/coughv...
# 3421  /content/drive/My Drive/Colab Notebooks/coswar...
# 3422  /content/drive/My Drive/Colab Notebooks/coswar...
# 3423  /content/drive/My Drive/Colab Notebooks/coughv...
# 3424  /content/drive/My Drive/Colab Notebooks/coughv...
# 3425  /content/drive/My Drive/Colab Notebooks/coughv...
# 3426  /content/drive/My Drive/Colab Notebooks/coughv...
# 3427  /content/drive/My Drive/Colab Notebooks/coswar...
# 3428  /content/drive/My Drive/Colab Notebooks/coughv...
# 3429  /content/drive/My Drive/Colab Notebooks/coswar...
#
#                                              image_file    source  \
# 3420  /content/drive/My Drive/Colab Notebooks/coughv...  coughvid
# 3421  /content/drive/My Drive/Colab Notebooks/coswar...   coswara
# 3422  /content/drive/My Drive/Colab Notebooks/coswar...   coswara
# 3423  /content/drive/My Drive/Colab Notebooks/coughv...  coughvid
# 3424  /content/drive/My Drive/Colab Notebooks/coughv...  coughvid
# 3425  /content/drive/My Drive/Colab Notebooks/coughv...  coughvid
# 3426  /content/drive/My Drive/Colab Notebooks/coughv...  coughvid
# 3427  /content/drive/My Drive/Colab Notebooks/coswar...   coswara
# 3428  /content/drive/My Drive/Colab Notebooks/coughv...  coughvid
# 3429  /content/drive/My Drive/Colab Notebooks/coswar...   coswara
#
#       cough_detected
# 3420          0.9962
# 3421             NaN
# 3422             NaN
# 3423          1.0000
# 3424          0.5410
# 3425          0.9636
# 3426          0.9583
# 3427             NaN
# 3428          0.9082
# 3429             NaN
#                                      id   age  gender    status  \
# 0          Zb2Inq1UVhcMnWA41GpKyRdF4z62  66.0  female   healthy
# 1  c4138919-bd2c-4e24-9fcf-582e428c7d27  37.0  female   healthy
# 2          ygiPwZYsKFetOejhxWXB6rKSHAf2  66.0    male  COVID-19
# 3  ec8ddd1e-d555-490f-9719-70a99c1c6993  29.0    male   healthy
# 4          CFkIEzwZ5PcogCElOD2K3RJQzmh1  44.0    male   healthy
# 5  68b505f9-1bf6-4a96-be6a-6cebfc73a974   NaN  female   healthy
# 6  b22dc80a-2eec-4b9f-a69b-7eb5353a08e8  28.0  female   healthy
# 7  428c81f6-943c-4679-a034-ec004e26d040  50.0    male   healthy
# 8  17406b1b-fe8e-4325-bbf2-3a0234e65f2b  54.0  female   healthy
# 9  587204a9-b8d4-4f10-b70c-cbf2db847af1  50.0    male   healthy
#
#                                           audio_file  \
# 0  /content/drive/My Drive/Colab Notebooks/coswar...
# 1  /content/drive/My Drive/Colab Notebooks/coughv...
# 2  /content/drive/My Drive/Colab Notebooks/coswar...
# 3  /content/drive/My Drive/Colab Notebooks/coughv...
# 4  /content/drive/My Drive/Colab Notebooks/coswar...
# 5  /content/drive/My Drive/Colab Notebooks/coughv...
# 6  /content/drive/My Drive/Colab Notebooks/coughv...
# 7  /content/drive/My Drive/Colab Notebooks/coughv...
# 8  /content/drive/My Drive/Colab Notebooks/coughv...
# 9  /content/drive/My Drive/Colab Notebooks/coughv...
#
#                                           image_file    source  cough_detected
# 0  /content/drive/My Drive/Colab Notebooks/coswar...   coswara             NaN
# 1  /content/drive/My Drive/Colab Notebooks/coughv...  coughvid          1.0000
# 2  /content/drive/My Drive/Colab Notebooks/coswar...   coswara             NaN
# 3  /content/drive/My Drive/Colab Notebooks/coughv...  coughvid          0.7849
# 4  /content/drive/My Drive/Colab Notebooks/coswar...   coswara             NaN
# 5  /content/drive/My Drive/Colab Notebooks/coughv...  coughvid          0.9859
# 6  /content/drive/My Drive/Colab Notebooks/coughv...  coughvid          0.8467
# 7  /content/drive/My Drive/Colab Notebooks/coughv...  coughvid          0.9867
# 8  /content/drive/My Drive/Colab Notebooks/coughv...  coughvid          0.6240
# 9  /content/drive/My Drive/Colab Notebooks/coughv...  coughvid          0.8438
# status
# COVID-19     832
# healthy     7149
# Name: status, dtype: int64
# status
# COVID-19     321
# healthy     3099
# Name: status, dtype: int64

# %% [markdown]
# # **Simple random undersampling.**
#
# Removing enough healthy samples to balance the datasets. Choice of sample to remove is at random.

# %%
df_healthy = df_train.loc[df_train.status == 'healthy']
df_covid = df_train.loc[df_train.status == 'COVID-19']

#Shuffle healthy samples before removing any
df_healthy = df_healthy.sample(frac = 1)

#Select the same number of healthy samples as covid samples
df_healthy = df_healthy[:df_covid.shape[0]]

#Put healthy and covid back together in one dataframe and shuffle
df_resampled = pd.concat([df_healthy,df_covid])
df_resampled = df_resampled.sample(frac = 1)

print (df_resampled.shape)
print (df_healthy.shape)
print (df_covid.shape)
# Out:
# (1664, 8)
# (832, 8)
# (832, 8)

# %% [markdown]
# Create input pipeline using ImageDataGenerator.

# %%
# Always run this code.

batch_size = 50 #reduced batch size as there are less samples overall and datasets are now balanced.
img_height = 288
img_width = 432

# Rescaling of data moved to first layer of model
datagen = tf.keras.preprocessing.image.ImageDataGenerator()

train_data = datagen.flow_from_dataframe(df_resampled, x_col = "image_file", y_col = "status", 
                                               target_size = (img_height,img_width),  
                                               class_mode = "binary", batch_size = batch_size, 
                                               shuffle = True, validate_filenames = True)

val_data = datagen.flow_from_dataframe(df_val, x_col = "image_file", y_col = "status", 
                                           target_size = (img_height,img_width), 
                                           class_mode = "binary", batch_size = batch_size, 
                                           shuffle = False, validate_filenames = True)
# Out:
# Found 1664 validated image filenames belonging to 2 classes.
# Found 3420 validated image filenames belonging to 2 classes.

# %% [markdown]
# # Creating Dataset

# %%
# Always run this code.
# Creating Datasets using ImageDatagenerator

train_dataset = tf.data.Dataset.from_generator(
    lambda: train_data,  
    output_types = (tf.float32 , tf.float32) , # output dtype
    output_shapes = ([None , 288 , 432 , 3] , [None , ]) # The 'None' enables different batch sizes when training.
)

valid_dataset = tf.data.Dataset.from_generator(
    lambda: val_data, 
    output_types = (tf.float32 , tf.float32), 
    output_shapes = ([None , 288 , 432 , 3] , [None , ])
)

train_dataset , valid_dataset
# Out:
# (<FlatMapDataset element_spec=(TensorSpec(shape=(None, 288, 432, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.float32, name=None))>,
#  <FlatMapDataset element_spec=(TensorSpec(shape=(None, 288, 432, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.float32, name=None))>)

# %% [markdown]
# Need to add cardinality as otherwise the model will not know how many images there are.

# %%
# Always run this code.
train_dataset = train_dataset.apply(tf.data.experimental.assert_cardinality(df_resampled.shape[0])) #Check these numbers with validated files found in data generator section.
valid_dataset = valid_dataset.apply(tf.data.experimental.assert_cardinality(df_val.shape[0]))

len(train_dataset) , len(valid_dataset)
# Out:
# (1664, 3420)

# %% [markdown]
# Prefetching to make model faster.

# %%
train_dataset = train_dataset.prefetch(buffer_size=tf.data.AUTOTUNE)
valid_dataset = valid_dataset.prefetch(buffer_size=tf.data.AUTOTUNE)

# %% [markdown]
# # CNN Network

# %% [markdown]
# Although there are built in measures for precision and recall, there are not the equivalent measures of specificity and negative prediction rate so I have had to create custom metrics for those.
#
# I have used example in (tf.keras.metrics.Metric | TensorFlow Core v2.7.0) for Precision
#  and changed it to calculate the metrics I need.

# %%
# Always run this code.
from keras.utils import metrics_utils
from keras.utils.generic_utils import to_list
from keras import backend
class Specificity(tf.keras.metrics.Metric):
  def __init__(self,
               thresholds=None,
               top_k=None,
               class_id=None,
               name=None,
               dtype=None):
    super(Specificity, self).__init__(name=name, dtype=dtype)
    self.init_thresholds = thresholds
    self.top_k = top_k
    self.class_id = class_id

    default_threshold = 0.5 if top_k is None else metrics_utils.NEG_INF
    self.thresholds = metrics_utils.parse_init_thresholds(
        thresholds, default_threshold=default_threshold)
    self._thresholds_distributed_evenly = (
        metrics_utils.is_evenly_distributed_thresholds(self.thresholds))
    self.true_negatives = self.add_weight(
        'true_negatives',
        shape=(len(self.thresholds),),
        initializer=tf.compat.v1.zeros_initializer)
    self.false_positives = self.add_weight(
        'false_positives',
        shape=(len(self.thresholds),),
        initializer=tf.compat.v1.zeros_initializer)

  def update_state(self, y_true, y_pred, sample_weight=None):
    """Accumulates true positive and false positive statistics.
    Args:
      y_true: The ground truth values, with the same dimensions as `y_pred`.
        Will be cast to `bool`.
      y_pred: The predicted values. Each element must be in the range `[0, 1]`.
      sample_weight: Optional weighting of each example. Defaults to 1. Can be a
        `Tensor` whose rank is either 0, or the same rank as `y_true`, and must
        be broadcastable to `y_true`.
    Returns:
      Update op.
    """
    return metrics_utils.update_confusion_matrix_variables(
        {
            metrics_utils.ConfusionMatrix.TRUE_NEGATIVES: self.true_negatives,
            metrics_utils.ConfusionMatrix.FALSE_POSITIVES: self.false_positives
        },
        y_true,
        y_pred,
        thresholds=self.thresholds,
        thresholds_distributed_evenly=self._thresholds_distributed_evenly,
        top_k=self.top_k,
        class_id=self.class_id,
        sample_weight=sample_weight)

  def result(self):
    result = tf.math.divide_no_nan(
        self.true_negatives,
        tf.math.add(self.true_negatives, self.false_positives))
    return result[0] if len(self.thresholds) == 1 else result

  def reset_state(self):
    num_thresholds = len(to_list(self.thresholds))
    backend.batch_set_value([(v, np.zeros((num_thresholds,)))
                             for v in (self.true_negatives,
                                       self.false_positives)])

  def get_config(self):
    config = {
        'thresholds': self.init_thresholds,
        'top_k': self.top_k,
        'class_id': self.class_id
    }
    base_config = super(Specificity, self).get_config()
    return dict(list(base_config.items()) + list(config.items()))

# %%
# Always run this code.
from keras.utils import metrics_utils
from keras.utils.generic_utils import to_list
from keras import backend
class NPV(tf.keras.metrics.Metric):
  def __init__(self,
               thresholds=None,
               top_k=None,
               class_id=None,
               name=None,
               dtype=None):
    super(NPV, self).__init__(name=name, dtype=dtype)
    self.init_thresholds = thresholds
    self.top_k = top_k
    self.class_id = class_id

    default_threshold = 0.5 if top_k is None else metrics_utils.NEG_INF
    self.thresholds = metrics_utils.parse_init_thresholds(
        thresholds, default_threshold=default_threshold)
    self._thresholds_distributed_evenly = (
        metrics_utils.is_evenly_distributed_thresholds(self.thresholds))
    self.true_negatives = self.add_weight(
        'true_negatives',
        shape=(len(self.thresholds),),
        initializer=tf.compat.v1.zeros_initializer)
    self.false_negatives = self.add_weight(
        'false_negatives',
        shape=(len(self.thresholds),),
        initializer=tf.compat.v1.zeros_initializer)

  def update_state(self, y_true, y_pred, sample_weight=None):
    """Accumulates true positive and false positive statistics.
    Args:
      y_true: The ground truth values, with the same dimensions as `y_pred`.
        Will be cast to `bool`.
      y_pred: The predicted values. Each element must be in the range `[0, 1]`.
      sample_weight: Optional weighting of each example. Defaults to 1. Can be a
        `Tensor` whose rank is either 0, or the same rank as `y_true`, and must
        be broadcastable to `y_true`.
    Returns:
      Update op.
    """
    return metrics_utils.update_confusion_matrix_variables(
        {
            metrics_utils.ConfusionMatrix.TRUE_NEGATIVES: self.true_negatives,
            metrics_utils.ConfusionMatrix.FALSE_NEGATIVES: self.false_negatives
        },
        y_true,
        y_pred,
        thresholds=self.thresholds,
        thresholds_distributed_evenly=self._thresholds_distributed_evenly,
        top_k=self.top_k,
        class_id=self.class_id,
        sample_weight=sample_weight)

  def result(self):
    result = tf.math.divide_no_nan(
        self.true_negatives,
        tf.math.add(self.true_negatives, self.false_negatives))
    return result[0] if len(self.thresholds) == 1 else result

  def reset_state(self):
    num_thresholds = len(to_list(self.thresholds))
    backend.batch_set_value([(v, np.zeros((num_thresholds,)))
                             for v in (self.true_negatives,
                                       self.false_negatives)])

  def get_config(self):
    config = {
        'thresholds': self.init_thresholds,
        'top_k': self.top_k,
        'class_id': self.class_id
    }
    base_config = super(NPV, self).get_config()
    return dict(list(base_config.items()) + list(config.items()))

# %% [markdown]
# # **Metrics available for use**

# %%
# Always run this cell.
precision = tf.keras.metrics.Precision(name = "precision")
recall = tf.keras.metrics.Recall(name = "recall")
specificity = Specificity(name = "specificity")
TP = tf.keras.metrics.TruePositives(name = "TP") 
FP = tf.keras.metrics.FalsePositives(name = "FP")
FN = tf.keras.metrics.FalseNegatives(name = "FN")
TN = tf.keras.metrics.TrueNegatives(name = "TN")
auc = tf.keras.metrics.AUC(name = "auc")
npv = NPV(name = "NPV")

# %% [markdown]
# # **Fit model on the training dataset**

# %%
#Run this cell to create model or use next cell to load existing model.
model_name = "Covid_Model_undersampling_1.h5" #Change name here for each new model

model = keras.Sequential([              

    #Rescale the pixel values (integers between 0 and 255) to [0,1]. 
    layers.Rescaling(1./255, input_shape=(img_height, img_width, 3)), 
    
    # Block One
    layers.Conv2D(filters=32, kernel_size=3, activation='relu', padding='same',
                  input_shape =[288,432,3]),
    layers.BatchNormalization(),
    layers.MaxPool2D(pool_size = (2,2)),

    # Block Two
    layers.Conv2D(filters=64, kernel_size=3, activation='relu', padding='valid'),
    layers.BatchNormalization(),
    layers.MaxPool2D(pool_size = (2,2)),

    # Block Three
    layers.Conv2D(filters=128, kernel_size=3, activation='relu', padding='valid'),
    layers.BatchNormalization(),
    layers.MaxPool2D(pool_size = (2,2)),

    # Block Four
    layers.Conv2D(filters=256, kernel_size=3, activation='relu', padding='valid'),
    layers.BatchNormalization(),
    layers.MaxPool2D(pool_size = (2,2)),

    # Block Five
    layers.Conv2D(filters=512, kernel_size=3, activation='relu', padding='valid'),
    layers.BatchNormalization(),
    layers.MaxPool2D(pool_size = (2,2)),

    # Head
    layers.Flatten(),
    layers.Dropout(0.25),
    layers.Dense(128, activation='relu'),
    layers.Dropout(0.25),
    layers.Dense(1, activation='sigmoid'),
])

model._name= model_name[:-3]

model_plots_folder = os.path.join(folder,'model_plots')

# Save model summaries to a text file.
with open(os.path.join(model_plots_folder,'Model_summaries.txt'), 'a') as f:
    with redirect_stdout(f):
        model.summary()

# Save model plots to individual png files.
plot_model(
    model,
    to_file=(os.path.join(model_plots_folder, model_name[:-3] + ".png")),
    show_shapes=True,
    show_dtype=False,
    show_layer_names=True,
    rankdir="TB",
    expand_nested=False,
    dpi=96,
    layer_range=None,
    show_layer_activations=False,
)

model.summary()
plot_model(model, show_shapes=True)

es_callback = EarlyStopping(monitor = 'val_auc',
                            mode='max',
                            min_delta = 0.01,
                            patience = 10,
                            restore_best_weights = True)

model.compile(
    optimizer=tf.keras.optimizers.Adam(epsilon=0.01),
    loss='binary_crossentropy',
    metrics=[TP, FP, FN, TN, 
             npv, specificity, 
             recall, auc
             ]
)

model_folder = '/content/drive/My Drive/Colab Notebooks/models/'
initial_weights = os.path.join(model_folder, 'initial_weights')
model.load_weights(initial_weights) #Initial weights created in colab notebook: Detecting_COVID_CNN_bias_initializer.

history = model.fit(
    train_dataset,
    validation_data=valid_dataset,
    callbacks = [es_callback],
    epochs = 30,
    steps_per_epoch=len(train_dataset) // batch_size,
    validation_steps=len(valid_dataset) // batch_size)

model.save(model_folder + model_name)
# Out:
# Model: "Covid_Model_undersampling_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling (Rescaling)       (None, 288, 432, 3)       0
#
#  conv2d (Conv2D)             (None, 288, 432, 32)      896
#
#  batch_normalization (BatchN  (None, 288, 432, 32)     128
#  ormalization)
#
#  max_pooling2d (MaxPooling2D  (None, 144, 216, 32)     0
#  )
#
#  conv2d_1 (Conv2D)           (None, 142, 214, 64)      18496
#
#  batch_normalization_1 (Batc  (None, 142, 214, 64)     256
#  hNormalization)
#
#  max_pooling2d_1 (MaxPooling  (None, 71, 107, 64)      0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 69, 105, 128)      73856
#
#  batch_normalization_2 (Batc  (None, 69, 105, 128)     512
#  hNormalization)
#
#  max_pooling2d_2 (MaxPooling  (None, 34, 52, 128)      0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 32, 50, 256)       295168
#
#  batch_normalization_3 (Batc  (None, 32, 50, 256)      1024
#  hNormalization)
#
#  max_pooling2d_3 (MaxPooling  (None, 16, 25, 256)      0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 14, 23, 512)       1180160
#
#  batch_normalization_4 (Batc  (None, 14, 23, 512)      2048
#  hNormalization)
#
#  max_pooling2d_4 (MaxPooling  (None, 7, 11, 512)       0
#  2D)
#
#  flatten (Flatten)           (None, 39424)             0
#
#  dropout (Dropout)           (None, 39424)             0
#
#  dense (Dense)               (None, 128)               5046400
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 6,619,073
# Trainable params: 6,617,089
# Non-trainable params: 1,984
# _________________________________________________________________
# Epoch 1/30
# 33/33 [==============================] - 1698s 52s/step - loss: 1.1058 - TP: 482.0000 - FP: 461.0000 - FN: 344.0000 - TN: 363.0000 - NPV: 0.5134 - specificity: 0.4405 - recall: 0.5835 - auc: 0.5101 - val_loss: 0.3521 - val_TP: 3082.0000 - val_FP: 318.0000 - val_FN: 0.0000e+00 - val_TN: 0.0000e+00 - val_NPV: 0.0000e+00 - val_specificity: 0.0000e+00 - val_recall: 1.0000 - val_auc: 0.4838
# Epoch 2/30
# 33/33 [==============================] - 39s 1s/step - loss: 0.6773 - TP: 513.0000 - FP: 377.0000 - FN: 293.0000 - TN: 431.0000 - NPV: 0.5953 - specificity: 0.5334 - recall: 0.6365 - auc: 0.6155 - val_loss: 0.5529 - val_TP: 3052.0000 - val_FP: 318.0000 - val_FN: 0.0000e+00 - val_TN: 0.0000e+00 - val_NPV: 0.0000e+00 - val_specificity: 0.0000e+00 - val_recall: 1.0000 - val_auc: 0.4797
# Epoch 3/30
# 33/33 [==============================] - 27s 823ms/step - loss: 0.6781 - TP: 547.0000 - FP: 402.0000 - FN: 253.0000 - TN: 412.0000 - NPV: 0.6195 - specificity: 0.5061 - recall: 0.6837 - auc: 0.6261 - val_loss: 1.1895 - val_TP: 0.0000e+00 - val_FP: 0.0000e+00 - val_FN: 3056.0000 - val_TN: 314.0000 - val_NPV: 0.0932 - val_specificity: 1.0000 - val_recall: 0.0000e+00 - val_auc: 0.4795
# Epoch 4/30
# 33/33 [==============================] - 27s 821ms/step - loss: 0.6380 - TP: 567.0000 - FP: 340.0000 - FN: 244.0000 - TN: 463.0000 - NPV: 0.6549 - specificity: 0.5766 - recall: 0.6991 - auc: 0.6818 - val_loss: 1.9678 - val_TP: 0.0000e+00 - val_FP: 0.0000e+00 - val_FN: 3054.0000 - val_TN: 316.0000 - val_NPV: 0.0938 - val_specificity: 1.0000 - val_recall: 0.0000e+00 - val_auc: 0.4802
# Epoch 5/30
# 33/33 [==============================] - 27s 819ms/step - loss: 0.6097 - TP: 611.0000 - FP: 317.0000 - FN: 212.0000 - TN: 474.0000 - NPV: 0.6910 - specificity: 0.5992 - recall: 0.7424 - auc: 0.7237 - val_loss: 2.1505 - val_TP: 0.0000e+00 - val_FP: 0.0000e+00 - val_FN: 3055.0000 - val_TN: 315.0000 - val_NPV: 0.0935 - val_specificity: 1.0000 - val_recall: 0.0000e+00 - val_auc: 0.4812
# Epoch 6/30
# 33/33 [==============================] - 27s 821ms/step - loss: 0.6111 - TP: 554.0000 - FP: 321.0000 - FN: 227.0000 - TN: 512.0000 - NPV: 0.6928 - specificity: 0.6146 - recall: 0.7093 - auc: 0.7236 - val_loss: 2.6524 - val_TP: 0.0000e+00 - val_FP: 0.0000e+00 - val_FN: 3052.0000 - val_TN: 318.0000 - val_NPV: 0.0944 - val_specificity: 1.0000 - val_recall: 0.0000e+00 - val_auc: 0.4827
# Epoch 7/30
# 33/33 [==============================] - 27s 823ms/step - loss: 0.5559 - TP: 628.0000 - FP: 269.0000 - FN: 191.0000 - TN: 526.0000 - NPV: 0.7336 - specificity: 0.6616 - recall: 0.7668 - auc: 0.7836 - val_loss: 1.6366 - val_TP: 10.0000 - val_FP: 1.0000 - val_FN: 3044.0000 - val_TN: 315.0000 - val_NPV: 0.0938 - val_specificity: 0.9968 - val_recall: 0.0033 - val_auc: 0.4822
# Epoch 8/30
# 33/33 [==============================] - 26s 815ms/step - loss: 0.5219 - TP: 659.0000 - FP: 253.0000 - FN: 160.0000 - TN: 542.0000 - NPV: 0.7721 - specificity: 0.6818 - recall: 0.8046 - auc: 0.8192 - val_loss: 0.6850 - val_TP: 2018.0000 - val_FP: 213.0000 - val_FN: 1034.0000 - val_TN: 105.0000 - val_NPV: 0.0922 - val_specificity: 0.3302 - val_recall: 0.6612 - val_auc: 0.4877
# Epoch 9/30
# 33/33 [==============================] - 27s 831ms/step - loss: 0.4970 - TP: 588.0000 - FP: 204.0000 - FN: 188.0000 - TN: 634.0000 - NPV: 0.7713 - specificity: 0.7566 - recall: 0.7577 - auc: 0.8404 - val_loss: 0.4901 - val_TP: 2815.0000 - val_FP: 288.0000 - val_FN: 239.0000 - val_TN: 28.0000 - val_NPV: 0.1049 - val_specificity: 0.0886 - val_recall: 0.9217 - val_auc: 0.5015
# Epoch 10/30
# 33/33 [==============================] - 27s 821ms/step - loss: 0.4510 - TP: 704.0000 - FP: 198.0000 - FN: 119.0000 - TN: 593.0000 - NPV: 0.8329 - specificity: 0.7497 - recall: 0.8554 - auc: 0.8761 - val_loss: 0.7223 - val_TP: 1484.0000 - val_FP: 133.0000 - val_FN: 1571.0000 - val_TN: 182.0000 - val_NPV: 0.1038 - val_specificity: 0.5778 - val_recall: 0.4858 - val_auc: 0.5387
# Epoch 11/30
# 33/33 [==============================] - 27s 839ms/step - loss: 0.4229 - TP: 691.0000 - FP: 173.0000 - FN: 120.0000 - TN: 630.0000 - NPV: 0.8400 - specificity: 0.7846 - recall: 0.8520 - auc: 0.8911 - val_loss: 0.5372 - val_TP: 2676.0000 - val_FP: 263.0000 - val_FN: 381.0000 - val_TN: 50.0000 - val_NPV: 0.1160 - val_specificity: 0.1597 - val_recall: 0.8754 - val_auc: 0.5625
# Epoch 12/30
# 33/33 [==============================] - 27s 818ms/step - loss: 0.4385 - TP: 673.0000 - FP: 222.0000 - FN: 125.0000 - TN: 594.0000 - NPV: 0.8261 - specificity: 0.7279 - recall: 0.8434 - auc: 0.8768 - val_loss: 0.7096 - val_TP: 1620.0000 - val_FP: 123.0000 - val_FN: 1433.0000 - val_TN: 194.0000 - val_NPV: 0.1192 - val_specificity: 0.6120 - val_recall: 0.5306 - val_auc: 0.6036
# Epoch 13/30
# 33/33 [==============================] - 27s 819ms/step - loss: 0.3235 - TP: 719.0000 - FP: 115.0000 - FN: 97.0000 - TN: 683.0000 - NPV: 0.8756 - specificity: 0.8559 - recall: 0.8811 - auc: 0.9438 - val_loss: 0.4314 - val_TP: 2856.0000 - val_FP: 283.0000 - val_FN: 197.0000 - val_TN: 34.0000 - val_NPV: 0.1472 - val_specificity: 0.1073 - val_recall: 0.9355 - val_auc: 0.5920
# Epoch 14/30
# 33/33 [==============================] - 27s 818ms/step - loss: 0.2771 - TP: 749.0000 - FP: 98.0000 - FN: 69.0000 - TN: 698.0000 - NPV: 0.9100 - specificity: 0.8769 - recall: 0.9156 - auc: 0.9608 - val_loss: 0.4158 - val_TP: 2845.0000 - val_FP: 272.0000 - val_FN: 210.0000 - val_TN: 43.0000 - val_NPV: 0.1700 - val_specificity: 0.1365 - val_recall: 0.9313 - val_auc: 0.5852
# Epoch 15/30
# 33/33 [==============================] - 27s 829ms/step - loss: 0.2648 - TP: 728.0000 - FP: 107.0000 - FN: 60.0000 - TN: 719.0000 - NPV: 0.9230 - specificity: 0.8705 - recall: 0.9239 - auc: 0.9617 - val_loss: 0.4550 - val_TP: 2668.0000 - val_FP: 241.0000 - val_FN: 387.0000 - val_TN: 74.0000 - val_NPV: 0.1605 - val_specificity: 0.2349 - val_recall: 0.8733 - val_auc: 0.6072
# Epoch 16/30
# 33/33 [==============================] - 27s 822ms/step - loss: 0.2076 - TP: 772.0000 - FP: 76.0000 - FN: 52.0000 - TN: 714.0000 - NPV: 0.9321 - specificity: 0.9038 - recall: 0.9369 - auc: 0.9794 - val_loss: 0.5118 - val_TP: 2517.0000 - val_FP: 208.0000 - val_FN: 536.0000 - val_TN: 109.0000 - val_NPV: 0.1690 - val_specificity: 0.3438 - val_recall: 0.8244 - val_auc: 0.6081
# Epoch 17/30
# 33/33 [==============================] - 27s 819ms/step - loss: 0.1514 - TP: 781.0000 - FP: 43.0000 - FN: 39.0000 - TN: 751.0000 - NPV: 0.9506 - specificity: 0.9458 - recall: 0.9524 - auc: 0.9874 - val_loss: 0.5470 - val_TP: 2433.0000 - val_FP: 203.0000 - val_FN: 620.0000 - val_TN: 114.0000 - val_NPV: 0.1553 - val_specificity: 0.3596 - val_recall: 0.7969 - val_auc: 0.6089
# Epoch 18/30
# 33/33 [==============================] - 27s 821ms/step - loss: 0.1410 - TP: 762.0000 - FP: 51.0000 - FN: 35.0000 - TN: 766.0000 - NPV: 0.9563 - specificity: 0.9376 - recall: 0.9561 - auc: 0.9891 - val_loss: 0.4638 - val_TP: 2659.0000 - val_FP: 230.0000 - val_FN: 394.0000 - val_TN: 87.0000 - val_NPV: 0.1809 - val_specificity: 0.2744 - val_recall: 0.8709 - val_auc: 0.6184
# Epoch 19/30
# 33/33 [==============================] - 26s 817ms/step - loss: 0.1412 - TP: 766.0000 - FP: 55.0000 - FN: 28.0000 - TN: 765.0000 - NPV: 0.9647 - specificity: 0.9329 - recall: 0.9647 - auc: 0.9897 - val_loss: 0.5268 - val_TP: 2518.0000 - val_FP: 213.0000 - val_FN: 535.0000 - val_TN: 104.0000 - val_NPV: 0.1628 - val_specificity: 0.3281 - val_recall: 0.8248 - val_auc: 0.6264
# Epoch 20/30
# 33/33 [==============================] - 27s 830ms/step - loss: 0.1652 - TP: 745.0000 - FP: 57.0000 - FN: 46.0000 - TN: 766.0000 - NPV: 0.9433 - specificity: 0.9307 - recall: 0.9418 - auc: 0.9837 - val_loss: 1.0833 - val_TP: 1754.0000 - val_FP: 122.0000 - val_FN: 1299.0000 - val_TN: 195.0000 - val_NPV: 0.1305 - val_specificity: 0.6151 - val_recall: 0.5745 - val_auc: 0.6290
# Epoch 21/30
# 33/33 [==============================] - 26s 817ms/step - loss: 0.1508 - TP: 789.0000 - FP: 58.0000 - FN: 38.0000 - TN: 729.0000 - NPV: 0.9505 - specificity: 0.9263 - recall: 0.9541 - auc: 0.9871 - val_loss: 1.1016 - val_TP: 1829.0000 - val_FP: 132.0000 - val_FN: 1224.0000 - val_TN: 185.0000 - val_NPV: 0.1313 - val_specificity: 0.5836 - val_recall: 0.5991 - val_auc: 0.6070
# Epoch 22/30
# 33/33 [==============================] - 27s 823ms/step - loss: 0.1279 - TP: 782.0000 - FP: 38.0000 - FN: 37.0000 - TN: 757.0000 - NPV: 0.9534 - specificity: 0.9522 - recall: 0.9548 - auc: 0.9909 - val_loss: 0.6069 - val_TP: 2579.0000 - val_FP: 225.0000 - val_FN: 472.0000 - val_TN: 94.0000 - val_NPV: 0.1661 - val_specificity: 0.2947 - val_recall: 0.8453 - val_auc: 0.6084
# Epoch 23/30
# 33/33 [==============================] - 27s 833ms/step - loss: 0.1816 - TP: 747.0000 - FP: 63.0000 - FN: 52.0000 - TN: 752.0000 - NPV: 0.9353 - specificity: 0.9227 - recall: 0.9349 - auc: 0.9807 - val_loss: 0.9732 - val_TP: 2062.0000 - val_FP: 154.0000 - val_FN: 991.0000 - val_TN: 163.0000 - val_NPV: 0.1412 - val_specificity: 0.5142 - val_recall: 0.6754 - val_auc: 0.6339
# Epoch 24/30
# 33/33 [==============================] - 26s 815ms/step - loss: 0.1247 - TP: 764.0000 - FP: 34.0000 - FN: 34.0000 - TN: 782.0000 - NPV: 0.9583 - specificity: 0.9583 - recall: 0.9574 - auc: 0.9914 - val_loss: 1.7543 - val_TP: 1474.0000 - val_FP: 100.0000 - val_FN: 1578.0000 - val_TN: 218.0000 - val_NPV: 0.1214 - val_specificity: 0.6855 - val_recall: 0.4830 - val_auc: 0.6233
# Epoch 25/30
# 33/33 [==============================] - 27s 827ms/step - loss: 0.0853 - TP: 784.0000 - FP: 28.0000 - FN: 20.0000 - TN: 782.0000 - NPV: 0.9751 - specificity: 0.9654 - recall: 0.9751 - auc: 0.9958 - val_loss: 1.3519 - val_TP: 1657.0000 - val_FP: 115.0000 - val_FN: 1393.0000 - val_TN: 205.0000 - val_NPV: 0.1283 - val_specificity: 0.6406 - val_recall: 0.5433 - val_auc: 0.6228
# Epoch 26/30
# 33/33 [==============================] - 27s 819ms/step - loss: 0.0473 - TP: 782.0000 - FP: 14.0000 - FN: 10.0000 - TN: 808.0000 - NPV: 0.9878 - specificity: 0.9830 - recall: 0.9874 - auc: 0.9992 - val_loss: 1.1227 - val_TP: 2079.0000 - val_FP: 154.0000 - val_FN: 973.0000 - val_TN: 164.0000 - val_NPV: 0.1442 - val_specificity: 0.5157 - val_recall: 0.6812 - val_auc: 0.6260
# Epoch 27/30
# 33/33 [==============================] - 27s 826ms/step - loss: 0.0382 - TP: 828.0000 - FP: 9.0000 - FN: 13.0000 - TN: 764.0000 - NPV: 0.9833 - specificity: 0.9884 - recall: 0.9845 - auc: 0.9994 - val_loss: 1.6096 - val_TP: 1759.0000 - val_FP: 126.0000 - val_FN: 1294.0000 - val_TN: 191.0000 - val_NPV: 0.1286 - val_specificity: 0.6025 - val_recall: 0.5762 - val_auc: 0.6179
# Epoch 28/30
# 33/33 [==============================] - 26s 814ms/step - loss: 0.0453 - TP: 791.0000 - FP: 16.0000 - FN: 10.0000 - TN: 797.0000 - NPV: 0.9876 - specificity: 0.9803 - recall: 0.9875 - auc: 0.9989 - val_loss: 0.8176 - val_TP: 2407.0000 - val_FP: 191.0000 - val_FN: 646.0000 - val_TN: 126.0000 - val_NPV: 0.1632 - val_specificity: 0.3975 - val_recall: 0.7884 - val_auc: 0.6356
# Epoch 29/30
# 33/33 [==============================] - 26s 817ms/step - loss: 0.0639 - TP: 793.0000 - FP: 25.0000 - FN: 18.0000 - TN: 778.0000 - NPV: 0.9774 - specificity: 0.9689 - recall: 0.9778 - auc: 0.9977 - val_loss: 1.2856 - val_TP: 2135.0000 - val_FP: 160.0000 - val_FN: 920.0000 - val_TN: 155.0000 - val_NPV: 0.1442 - val_specificity: 0.4921 - val_recall: 0.6989 - val_auc: 0.6355
# Epoch 30/30
# 33/33 [==============================] - 27s 821ms/step - loss: 0.0687 - TP: 773.0000 - FP: 25.0000 - FN: 15.0000 - TN: 801.0000 - NPV: 0.9816 - specificity: 0.9697 - recall: 0.9810 - auc: 0.9974 - val_loss: 1.1380 - val_TP: 2232.0000 - val_FP: 188.0000 - val_FN: 822.0000 - val_TN: 128.0000 - val_NPV: 0.1347 - val_specificity: 0.4051 - val_recall: 0.7308 - val_auc: 0.6069

# %% [markdown]
# # **Run on test dataset**

# %%
# Import Test dataframe
df_test = pd.read_csv(os.path.join(folder, 'df_test.csv'), index_col=0)

#Rescale images in the same way as for train and validation sets
test_data = datagen.flow_from_dataframe(df_test, x_col = "image_file", y_col = "status", 
                                           target_size = (288,432), 
                                           class_mode = "binary", batch_size = batch_size, 
                                           shuffle = False, validate_filenames = True)

#Create dataset
test_dataset = tf.data.Dataset.from_generator(
    lambda: test_data, 
    output_types = (tf.float32 , tf.float32), 
    output_shapes = ([None , 288 , 432 , 3] , [None , ])
)

#Assert cardinality so the length can be used.
test_dataset = test_dataset.apply(tf.data.experimental.assert_cardinality(df_test.shape[0]))

_,TP,FP,FN,TN, Spec, npv, Recall, AUC = model.evaluate(test_dataset, steps = df_test.shape[0]//batch_size)
print('Confusion Matrix: ', TP, FP, FN, TN)
print('Test NPV: %.4f' % npv)
print('Test Specificity: %.4f' % Spec)
print('Test Recall: %.4f' % Recall)
print('Test ROC-AUC: %.4f' % AUC)
# Out:
# Found 1000 validated image filenames belonging to 2 classes.
# 20/20 [==============================] - 5s 248ms/step - loss: 1.0530 - TP: 505.0000 - FP: 44.0000 - FN: 381.0000 - TN: 70.0000 - NPV: 0.1552 - specificity: 0.6140 - recall: 0.5700 - auc: 0.6081
# Confusion Matrix:  505.0 44.0 381.0 70.0
# Test NPV: 0.6140
# Test Specificity: 0.1552
# Test Recall: 0.5700
# Test ROC-AUC: 0.6081

# %%
from tensorflow.keras.preprocessing import image
img_path = df_train.iloc[0,5] # fifth column is image_file
img = image.load_img(img_path, target_size=(288,432,3))
plt.imshow(img)
plt.show()

img_array = image.img_to_array(img)
img_batch = np.expand_dims(img_array, axis=0)
prediction = model.predict(img_batch).tolist()
print(prediction[0][0])
# Out:
# 0.9577639102935791

# %% [markdown]
# # **Resample using distribution of probabilities.**

# %%
#Reload best model so far comparing auc (Oversampling model)
model_folder = '/content/drive/My Drive/Colab Notebooks/models/'

custom_objects = {"NPV": NPV, "Specificity": Specificity}
with keras.utils.custom_object_scope(custom_objects):
    model = tf.keras.models.load_model(model_folder + "Covid_Model_oversampling.h5")

# %%
#Add new column
df_train["Predicted_Prob"] = 'Nan'

from tensorflow.keras.preprocessing import image

def predict_prob(row):
  img_path = row.image_file
  img = image.load_img(img_path, target_size=(288,432,3))
  img_array = image.img_to_array(img)
  img_batch = np.expand_dims(img_array, axis=0)
  prediction = model.predict(img_batch).tolist()
  row.Predicted_Prob = prediction[0][0]
  return row

df_train = df_train.apply(predict_prob, axis = 'columns')

df_train
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                                          id   age  gender    status  \
# 3420   6ea0f6b7-8110-4940-b848-0635be9b5978  29.0    male   healthy
# 3421           zM5GsorprLYElGQ3uJwnU0g0Fwr1  35.0    male  COVID-19
# 3422           bx564wHvi9d0HyJTtdi0haZuU493  28.0    male  COVID-19
# 3423   07e2f7e1-8e9b-4962-8701-fbe1224de7ef  28.0    male   healthy
# 3424   aeeb58ec-cefc-4d57-b2f5-db03cf502ae4   NaN  female   healthy
# ...                                     ...   ...     ...       ...
# 11396  4c21220c-04b3-4aa0-aac4-afede127213e   NaN  female   healthy
# 11397  285e7f6f-503a-41f0-ac3b-173433a8cf40  43.0    male  COVID-19
# 11398  6478394b-6c6d-451a-8887-996a8e6d8fb8  27.0    male   healthy
# 11399          av4p9I9aBGfNYwrwkh4jEiEk1lE2  43.0  female   healthy
# 11400  abeb8c3f-f379-4989-8ce9-d9d509c08d97  37.0    male   healthy
#
#                                               audio_file  \
# 3420   /content/drive/My Drive/Colab Notebooks/coughv...
# 3421   /content/drive/My Drive/Colab Notebooks/coswar...
# 3422   /content/drive/My Drive/Colab Notebooks/coswar...
# 3423   /content/drive/My Drive/Colab Notebooks/coughv...
# 3424   /content/drive/My Drive/Colab Notebooks/coughv...
# ...                                                  ...
# 11396  /content/drive/My Drive/Colab Notebooks/coughv...
# 11397  /content/drive/My Drive/Colab Notebooks/coughv...
# 11398  /content/drive/My Drive/Colab Notebooks/coughv...
# 11399  /content/drive/My Drive/Colab Notebooks/coswar...
# 11400  /content/drive/My Drive/Colab Notebooks/coughv...
#
#                                               image_file    source  \
# 3420   /content/drive/My Drive/Colab Notebooks/coughv...  coughvid
# 3421   /content/drive/My Drive/Colab Notebooks/coswar...   coswara
# 3422   /content/drive/My Drive/Colab Notebooks/coswar...   coswara
# 3423   /content/drive/My Drive/Colab Notebooks/coughv...  coughvid
# 3424   /content/drive/My Drive/Colab Notebooks/coughv...  coughvid
# ...                                                  ...       ...
# 11396  /content/drive/My Drive/Colab Notebooks/coughv...  coughvid
# 11397  /content/drive/My Drive/Colab Notebooks/coughv...  coughvid
# 11398  /content/drive/My Drive/Colab Notebooks/coughv...  coughvid
# 11399  /content/drive/My Drive/Colab Notebooks/coswar...   coswara
# 11400  /content/drive/My Drive/Colab Notebooks/coughv...  coughvid
#
#        cough_detected  Predicted_Prob
# 3420           0.9962        0.949207
# 3421              NaN        0.004331
# 3422              NaN        0.033578
# 3423           1.0000        0.985296
# 3424           0.5410        0.880995
# ...               ...             ...
# 11396          0.5809        0.927315
# 11397          1.0000        0.051105
# 11398          0.9336        0.964138
# 11399             NaN        0.964002
# 11400          0.5071        0.907091
#
# [7981 rows x 9 columns]

# %% [markdown]
# # Draw a scatter graph.

# %%
x = df_train.loc[:,'status']
y = df_train.loc[:,'Predicted_Prob']
plt.scatter(x, y)
plt.show()

# %%
df_train.to_csv(os.path.join(folder,'df_train_with_predicted_prob.csv'))

# %%
df_train = pd.read_csv(os.path.join(folder,'df_train_with_predicted_prob.csv'), index_col = 0)
df_train
# Out:
#                                          id   age  gender    status  \
# 3420   7ef296e3-b692-4907-830e-2a47798f4509   NaN  female   healthy
# 3421           7sW9NvDUCfWdCR5bPANiS05bqRc2  26.0    male   healthy
# 3422   ac4ea2db-4fff-4a7f-a5fe-3a9ade2f1020   NaN  female  COVID-19
# 3423   62e23b57-4964-44e0-b5c2-35e1c487d6f9  60.0  female   healthy
# 3424   dfb974e5-65b0-4ea8-b10b-a6349d7e0cbe  22.0    male   healthy
# ...                                     ...   ...     ...       ...
# 11396  7d0f7c10-c2fb-4a0b-8917-00c1bbfa9ba9  42.0    male  COVID-19
# 11397  5e26c5da-ab49-4df1-ba6f-eb9550877934  46.0    male   healthy
# 11398          VQVtmKC3HwVHbY1xMTued5OOP4E2  36.0  female   healthy
# 11399  e11c5a28-af63-4193-90aa-5ee8876c7fb3  55.0  female   healthy
# 11400  5eda54ee-a3cb-4624-8f28-d2f04b51e374  52.0    male   healthy
#
#                                               image_file    source  \
# 3420   /content/drive/My Drive/Colab Notebooks/coughv...  coughvid
# 3421   /content/drive/My Drive/Colab Notebooks/coswar...   coswara
# 3422   /content/drive/My Drive/Colab Notebooks/coughv...  coughvid
# 3423   /content/drive/My Drive/Colab Notebooks/coughv...  coughvid
# 3424   /content/drive/My Drive/Colab Notebooks/coughv...  coughvid
# ...                                                  ...       ...
# 11396  /content/drive/My Drive/Colab Notebooks/coughv...  coughvid
# 11397  /content/drive/My Drive/Colab Notebooks/coughv...  coughvid
# 11398  /content/drive/My Drive/Colab Notebooks/coswar...   coswara
# 11399  /content/drive/My Drive/Colab Notebooks/coughv...  coughvid
# 11400  /content/drive/My Drive/Colab Notebooks/coughv...  coughvid
#
#        cough_detected  Predicted_Prob
# 3420           0.9954        0.806775
# 3421              NaN        0.966155
# 3422           1.0000        0.048167
# 3423           0.9693        0.958514
# 3424           0.7407        0.989078
# ...               ...             ...
# 11396          1.0000        0.048044
# 11397          1.0000        0.933949
# 11398             NaN        0.903443
# 11399          0.9759        0.942117
# 11400          0.9862        0.212932
#
# [7981 rows x 8 columns]

# %% [markdown]
# # Remove healthy samples with a low predicted probability.

# %%
df_healthy = df_train.loc[df_train.status == 'healthy']
df_covid = df_train.loc[df_train.status == 'COVID-19']

#Order healthy samples by Predicted_Prob before removing any
df_healthy = df_healthy.sort_values('Predicted_Prob',ascending=False)

#Select the same number of healthy samples as covid samples
df_healthy = df_healthy[:df_covid.shape[0]]

#Put healthy and covid back together in one dataframe and shuffle
df_resampled = pd.concat([df_healthy,df_covid])
df_resampled = df_resampled.sample(frac = 1)

print (df_resampled.shape)
print (df_healthy.shape)
print (df_covid.shape)
# Out:
# (1664, 9)
# (832, 9)
# (832, 9)

# %% [markdown]
# Review changed distribution

# %%
x = df_resampled.loc[:,'status']
y = df_resampled.loc[:,'Predicted_Prob']
plt.scatter(x, y)
plt.show()

# %% [markdown]
# # Retrain Model.

# %%
# Always run this cell.
precision = tf.keras.metrics.Precision(name = "precision")
recall = tf.keras.metrics.Recall(name = "recall")
specificity = Specificity(name = "specificity")
TP = tf.keras.metrics.TruePositives(name = "TP") 
FP = tf.keras.metrics.FalsePositives(name = "FP")
FN = tf.keras.metrics.FalseNegatives(name = "FN")
TN = tf.keras.metrics.TrueNegatives(name = "TN")
auc = tf.keras.metrics.AUC(name = "auc")
npv = NPV(name = "NPV")

# %%
#Run this cell to create model or use next cell to load existing model.

batch_size = 50 #reduced batch size as there are less samples overall and datasets are now balanced.
img_height = 288
img_width = 432

# Rescaling of data moved to first layer of model
datagen = tf.keras.preprocessing.image.ImageDataGenerator()

train_data = datagen.flow_from_dataframe(df_resampled, x_col = "image_file", y_col = "status", 
                                               target_size = (img_height,img_width),  
                                               class_mode = "binary", batch_size = batch_size, 
                                               shuffle = True, validate_filenames = True)

val_data = datagen.flow_from_dataframe(df_val, x_col = "image_file", y_col = "status", 
                                           target_size = (img_height,img_width), 
                                           class_mode = "binary", batch_size = batch_size, 
                                           shuffle = False, validate_filenames = True)

train_dataset = tf.data.Dataset.from_generator(
    lambda: train_data,  
    output_types = (tf.float32 , tf.float32) , # output dtype
    output_shapes = ([None , 288 , 432 , 3] , [None , ]) # The 'None' enables different batch sizes when training.
)

valid_dataset = tf.data.Dataset.from_generator(
    lambda: val_data, 
    output_types = (tf.float32 , tf.float32), 
    output_shapes = ([None , 288 , 432 , 3] , [None , ])
)

train_dataset = train_dataset.apply(tf.data.experimental.assert_cardinality(df_resampled.shape[0])) #Check these numbers with validated files found in data generator section.
valid_dataset = valid_dataset.apply(tf.data.experimental.assert_cardinality(df_val.shape[0]))


model_name = "Covid_Model_undersampling_2.h5" #Change name here for each new model

model = keras.Sequential([              

    #Rescale the pixel values (integers between 0 and 255) to [0,1]. 
    layers.Rescaling(1./255, input_shape=(img_height, img_width, 3)), 
    
    # Block One
    layers.Conv2D(filters=32, kernel_size=3, activation='relu', padding='same',
                  input_shape =[288,432,3]),
    layers.BatchNormalization(),
    layers.MaxPool2D(pool_size = (2,2)),

    # Block Two
    layers.Conv2D(filters=64, kernel_size=3, activation='relu', padding='valid'),
    layers.BatchNormalization(),
    layers.MaxPool2D(pool_size = (2,2)),

    # Block Three
    layers.Conv2D(filters=128, kernel_size=3, activation='relu', padding='valid'),
    layers.BatchNormalization(),
    layers.MaxPool2D(pool_size = (2,2)),

    # Block Four
    layers.Conv2D(filters=256, kernel_size=3, activation='relu', padding='valid'),
    layers.BatchNormalization(),
    layers.MaxPool2D(pool_size = (2,2)),

    # Block Five
    layers.Conv2D(filters=512, kernel_size=3, activation='relu', padding='valid'),
    layers.BatchNormalization(),
    layers.MaxPool2D(pool_size = (2,2)),

    # Head
    layers.Flatten(),
    layers.Dropout(0.25),
    layers.Dense(128, activation='relu'),
    layers.Dropout(0.25),
    layers.Dense(1, activation='sigmoid'),
])

model._name= model_name[:-3]

model_plots_folder = os.path.join(folder,'model_plots')

# Save model summaries to a text file.
with open(os.path.join(model_plots_folder,'Model_summaries.txt'), 'a') as f:
    with redirect_stdout(f):
        model.summary()

# Save model plots to individual png files.
plot_model(
    model,
    to_file=(os.path.join(model_plots_folder, model_name[:-3] + ".png")),
    show_shapes=True,
    show_dtype=False,
    show_layer_names=True,
    rankdir="TB",
    expand_nested=False,
    dpi=96,
    layer_range=None,
    show_layer_activations=False,
)

model.summary()
plot_model(model, show_shapes=True)

es_callback = EarlyStopping(monitor = 'val_auc',
                            mode='max',
                            min_delta = 0.01,
                            patience = 10,
                            restore_best_weights = True)

model.compile(
    optimizer=tf.keras.optimizers.Adam(epsilon=0.01),
    loss='binary_crossentropy',
    metrics=[TP, FP, FN, TN, 
             npv, specificity, 
             recall, auc
             ]
)

model_folder = '/content/drive/My Drive/Colab Notebooks/models/'
initial_weights = os.path.join(model_folder, 'initial_weights')
model.load_weights(initial_weights) #Initial weights created in colab notebook: Detecting_COVID_CNN_bias_initializer.

history = model.fit(
    train_dataset,
    validation_data=valid_dataset,
    callbacks = [es_callback],
    epochs = 30,
    steps_per_epoch=len(train_dataset) // batch_size,
    validation_steps=len(valid_dataset) // batch_size)

model.save(model_folder + model_name)
# Out:
# Found 1664 validated image filenames belonging to 2 classes.
# Found 3420 validated image filenames belonging to 2 classes.
# Model: "Covid_Model_undersampling_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_2 (Rescaling)     (None, 288, 432, 3)       0
#
#  conv2d_10 (Conv2D)          (None, 288, 432, 32)      896
#
#  batch_normalization_10 (Bat  (None, 288, 432, 32)     128
#  chNormalization)
#
#  max_pooling2d_10 (MaxPoolin  (None, 144, 216, 32)     0
#  g2D)
#
#  conv2d_11 (Conv2D)          (None, 142, 214, 64)      18496
#
#  batch_normalization_11 (Bat  (None, 142, 214, 64)     256
#  chNormalization)
#
#  max_pooling2d_11 (MaxPoolin  (None, 71, 107, 64)      0
#  g2D)
#
#  conv2d_12 (Conv2D)          (None, 69, 105, 128)      73856
#
#  batch_normalization_12 (Bat  (None, 69, 105, 128)     512
#  chNormalization)
#
#  max_pooling2d_12 (MaxPoolin  (None, 34, 52, 128)      0
#  g2D)
#
#  conv2d_13 (Conv2D)          (None, 32, 50, 256)       295168
#
#  batch_normalization_13 (Bat  (None, 32, 50, 256)      1024
#  chNormalization)
#
#  max_pooling2d_13 (MaxPoolin  (None, 16, 25, 256)      0
#  g2D)
#
#  conv2d_14 (Conv2D)          (None, 14, 23, 512)       1180160
#
#  batch_normalization_14 (Bat  (None, 14, 23, 512)      2048
#  chNormalization)
#
#  max_pooling2d_14 (MaxPoolin  (None, 7, 11, 512)       0
#  g2D)
#
#  flatten_2 (Flatten)         (None, 39424)             0
#
#  dropout_4 (Dropout)         (None, 39424)             0
#
#  dense_4 (Dense)             (None, 128)               5046400
#
#  dropout_5 (Dropout)         (None, 128)               0
#
#  dense_5 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 6,619,073
# Trainable params: 6,617,089
# Non-trainable params: 1,984
# _________________________________________________________________
# Epoch 1/30
# 33/33 [==============================] - 30s 868ms/step - loss: 0.7868 - TP: 579.0000 - FP: 314.0000 - FN: 245.0000 - TN: 512.0000 - NPV: 0.6764 - specificity: 0.6199 - recall: 0.7027 - auc: 0.7284 - val_loss: 2.4496 - val_TP: 0.0000e+00 - val_FP: 0.0000e+00 - val_FN: 3082.0000 - val_TN: 318.0000 - val_NPV: 0.0935 - val_specificity: 1.0000 - val_recall: 0.0000e+00 - val_auc: 0.5074
# Epoch 2/30
# 33/33 [==============================] - 27s 835ms/step - loss: 0.4646 - TP: 650.0000 - FP: 199.0000 - FN: 159.0000 - TN: 606.0000 - NPV: 0.7922 - specificity: 0.7528 - recall: 0.8035 - auc: 0.8631 - val_loss: 7.4295 - val_TP: 0.0000e+00 - val_FP: 0.0000e+00 - val_FN: 3052.0000 - val_TN: 318.0000 - val_NPV: 0.0944 - val_specificity: 1.0000 - val_recall: 0.0000e+00 - val_auc: 0.5000
# Epoch 3/30
# 33/33 [==============================] - 27s 832ms/step - loss: 0.4131 - TP: 676.0000 - FP: 187.0000 - FN: 128.0000 - TN: 623.0000 - NPV: 0.8296 - specificity: 0.7691 - recall: 0.8408 - auc: 0.8926 - val_loss: 11.2330 - val_TP: 0.0000e+00 - val_FP: 0.0000e+00 - val_FN: 3056.0000 - val_TN: 314.0000 - val_NPV: 0.0932 - val_specificity: 1.0000 - val_recall: 0.0000e+00 - val_auc: 0.5000
# Epoch 4/30
# 33/33 [==============================] - 27s 827ms/step - loss: 0.3615 - TP: 706.0000 - FP: 163.0000 - FN: 100.0000 - TN: 645.0000 - NPV: 0.8658 - specificity: 0.7983 - recall: 0.8759 - auc: 0.9175 - val_loss: 14.7033 - val_TP: 0.0000e+00 - val_FP: 0.0000e+00 - val_FN: 3054.0000 - val_TN: 316.0000 - val_NPV: 0.0938 - val_specificity: 1.0000 - val_recall: 0.0000e+00 - val_auc: 0.5000
# Epoch 5/30
# 33/33 [==============================] - 27s 830ms/step - loss: 0.3468 - TP: 684.0000 - FP: 129.0000 - FN: 118.0000 - TN: 683.0000 - NPV: 0.8527 - specificity: 0.8411 - recall: 0.8529 - auc: 0.9256 - val_loss: 15.7037 - val_TP: 0.0000e+00 - val_FP: 0.0000e+00 - val_FN: 3055.0000 - val_TN: 315.0000 - val_NPV: 0.0935 - val_specificity: 1.0000 - val_recall: 0.0000e+00 - val_auc: 0.5000
# Epoch 6/30
# 33/33 [==============================] - 27s 842ms/step - loss: 0.2669 - TP: 750.0000 - FP: 116.0000 - FN: 69.0000 - TN: 679.0000 - NPV: 0.9078 - specificity: 0.8541 - recall: 0.9158 - auc: 0.9562 - val_loss: 16.7626 - val_TP: 0.0000e+00 - val_FP: 0.0000e+00 - val_FN: 3052.0000 - val_TN: 318.0000 - val_NPV: 0.0944 - val_specificity: 1.0000 - val_recall: 0.0000e+00 - val_auc: 0.5000
# Epoch 7/30
# 33/33 [==============================] - 27s 828ms/step - loss: 0.2435 - TP: 744.0000 - FP: 104.0000 - FN: 56.0000 - TN: 710.0000 - NPV: 0.9269 - specificity: 0.8722 - recall: 0.9300 - auc: 0.9633 - val_loss: 16.0615 - val_TP: 0.0000e+00 - val_FP: 0.0000e+00 - val_FN: 3054.0000 - val_TN: 316.0000 - val_NPV: 0.0938 - val_specificity: 1.0000 - val_recall: 0.0000e+00 - val_auc: 0.5000
# Epoch 8/30
# 33/33 [==============================] - 27s 831ms/step - loss: 0.1865 - TP: 743.0000 - FP: 72.0000 - FN: 50.0000 - TN: 749.0000 - NPV: 0.9374 - specificity: 0.9123 - recall: 0.9369 - auc: 0.9800 - val_loss: 15.4441 - val_TP: 0.0000e+00 - val_FP: 0.0000e+00 - val_FN: 3052.0000 - val_TN: 318.0000 - val_NPV: 0.0944 - val_specificity: 1.0000 - val_recall: 0.0000e+00 - val_auc: 0.5000
# Epoch 9/30
# 33/33 [==============================] - 27s 823ms/step - loss: 0.1472 - TP: 790.0000 - FP: 59.0000 - FN: 33.0000 - TN: 732.0000 - NPV: 0.9569 - specificity: 0.9254 - recall: 0.9599 - auc: 0.9869 - val_loss: 15.6067 - val_TP: 0.0000e+00 - val_FP: 0.0000e+00 - val_FN: 3054.0000 - val_TN: 316.0000 - val_NPV: 0.0938 - val_specificity: 1.0000 - val_recall: 0.0000e+00 - val_auc: 0.5000
# Epoch 10/30
# 33/33 [==============================] - 27s 826ms/step - loss: 0.1032 - TP: 793.0000 - FP: 39.0000 - FN: 26.0000 - TN: 756.0000 - NPV: 0.9668 - specificity: 0.9509 - recall: 0.9683 - auc: 0.9943 - val_loss: 15.0192 - val_TP: 0.0000e+00 - val_FP: 0.0000e+00 - val_FN: 3055.0000 - val_TN: 315.0000 - val_NPV: 0.0935 - val_specificity: 1.0000 - val_recall: 0.0000e+00 - val_auc: 0.5000
# Epoch 11/30
# 33/33 [==============================] - 27s 835ms/step - loss: 0.0905 - TP: 762.0000 - FP: 36.0000 - FN: 23.0000 - TN: 793.0000 - NPV: 0.9718 - specificity: 0.9566 - recall: 0.9707 - auc: 0.9955 - val_loss: 15.1329 - val_TP: 0.0000e+00 - val_FP: 0.0000e+00 - val_FN: 3057.0000 - val_TN: 313.0000 - val_NPV: 0.0929 - val_specificity: 1.0000 - val_recall: 0.0000e+00 - val_auc: 0.5000

# %%
#Reload model created in previous cell if previous cell has been run before.
model_folder = '/content/drive/My Drive/Colab Notebooks/models/'

custom_objects = {"NPV": NPV, "Specificity": Specificity}
with keras.utils.custom_object_scope(custom_objects):
    model = tf.keras.models.load_model(model_folder + "Covid_Model_undersampling_2.h5")

# %% [markdown]
# # Retest Model.

# %%
# Import Test dataframe
df_test = pd.read_csv(os.path.join(folder, 'df_test.csv'), index_col=0)

#Rescale images in the same way as for train and validation sets
test_data = datagen.flow_from_dataframe(df_test, x_col = "image_file", y_col = "status", 
                                           target_size = (288,432), 
                                           class_mode = "binary", batch_size = batch_size, 
                                           shuffle = False, validate_filenames = True)

#Create dataset
test_dataset = tf.data.Dataset.from_generator(
    lambda: test_data, 
    output_types = (tf.float32 , tf.float32), 
    output_shapes = ([None , 288 , 432 , 3] , [None , ])
)

#Assert cardinality so the length can be used.
test_dataset = test_dataset.apply(tf.data.experimental.assert_cardinality(df_test.shape[0]))

_,TP,FP,FN,TN, Spec, npv, Recall, AUC = model.evaluate(test_dataset, steps = df_test.shape[0]//batch_size)
print('Confusion Matrix: ', TP, FP, FN, TN)
print('Test NPV: %.4f' % npv)
print('Test Specificity: %.4f' % Spec)
print('Test Recall: %.4f' % Recall)
print('Test ROC-AUC: %.4f' % AUC)
# Out:
# Found 1000 validated image filenames belonging to 2 classes.
# 20/20 [==============================] - 5s 251ms/step - loss: 2.3963 - TP: 0.0000e+00 - FP: 0.0000e+00 - FN: 886.0000 - TN: 114.0000 - NPV: 0.1140 - specificity: 1.0000 - recall: 0.0000e+00 - auc: 0.4851
# Confusion Matrix:  0.0 0.0 886.0 114.0
# Test NPV: 1.0000
# Test Specificity: 0.1140
# Test Recall: 0.0000
# Test ROC-AUC: 0.4851

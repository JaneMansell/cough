# %% [markdown]
# Using a dataset of mfccs with a RNN-LSTM model with oversampling.
#
# The minority class is oversampled to match the majority class.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import warnings
warnings.simplefilter("ignore")
import os
import numpy as np
import matplotlib.pyplot as plt
import math
import json
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.utils import plot_model
from contextlib import redirect_stdout
import numpy as np
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras import optimizers
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_curve

# %%
folder = '/content/drive/My Drive/Colab Notebooks/COVID-19'
if not os.path.exists(folder):
  print(folder + ' does not exist')

mfcc_folder = os.path.join(folder, 'mfcc_json_files')
if not os.path.exists(mfcc_folder):
  print(mfcc_folder + ' does not exist')

# %% [markdown]
# Read in json files created previously in Extract_rawMFCCs.ipynb.

# %%
def load_jsonfile(path, filename):
  with open(os.path.join(path, filename)) as json_file:
    data = json.load(json_file)
  print("{} loaded".format(filename))
  return data

# %%
test_data = load_jsonfile(mfcc_folder, 'test_mfccs.json')
train_data = load_jsonfile(mfcc_folder, 'train_mfccs.json')
# Out:
# test_mfccs.json loaded
# train_mfccs.json loaded

# %% [markdown]
# Change labels to 0s and 1s

# %%
test_data_labels = []
for i in range (len(test_data["labels"])):
  if test_data["labels"][i] == 'healthy':
    test_data_labels.append(1)
  else:
    test_data_labels.append(0)

train_data_labels = []
for i in range (len(train_data["labels"])):
  if train_data["labels"][i] == 'healthy':
    train_data_labels.append(1)
  else:
    train_data_labels.append(0)

# %% [markdown]
# Create X_train, y_train, X_test, y_test

# %%
# Test data
X_test = np.array(test_data["mfcc"])
y_test = np.array(test_data_labels)

# Train data
X_train = np.array(train_data["mfcc"])
y_train = np.array(train_data_labels)

print("X_train shape: {}, y_train shape: {}, X_test shape: {}, y_test shape: {}".format(
    X_train.shape, y_train.shape, X_test.shape, y_test.shape))
# Out:
# X_train shape: (11401, 301, 13), y_train shape: (11401,), X_test shape: (1000, 301, 13), y_test shape: (1000,)

# %% [markdown]
# Split out a validation set

# %%
validation_size = 0.2
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=validation_size)

# %% [markdown]
# Check shape of X_train, y_train, X_val, y_val, X_test and y_test

# %%
print(X_train.shape)
print(y_train.shape)
print(X_val.shape)
print(y_val.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (9120, 301, 13)
# (9120,)
# (2281, 301, 13)
# (2281,)
# (1000, 301, 13)
# (1000,)

# %% [markdown]
# Oversample minority class in training set only.

# %%
# How many of each class in training set.
count0 = 0
count1 = 0
for i in range (y_train.shape[0]):
  if y_train[i] == 0:
    count0 += 1
  else:
    count1 +=1
print("0: {}, 1: {}".format(count0, count1))
print()
# Out:
# 0: 923, 1: 8197

# %%
data_0 = []
label_0 = []
data_1 = []
label_1 = []

for i in range (y_train.shape[0]):
  if y_train[i] == 0:
    data_0.append(X_train[i])
    label_0.append(y_train[i])
  else:
    data_1.append(X_train[i])
    label_1.append(y_train[i])

data_new = data_0 + data_1
label_new = label_0 + label_1

for i in range (int(count1/count0)-1):
  data_new += data_0
  label_new += label_0

oversampled_X_train = np.array(data_new)
oversampled_y_train = np.array(label_new)

print(oversampled_X_train)
print(oversampled_y_train)

print(oversampled_X_train.shape)
print(oversampled_y_train.shape)
# Out:
# [[[-2.31460345e+02 -1.10666308e-14  0.00000000e+00 ... -1.97655197e-15
#     0.00000000e+00 -1.34373226e-15]
#   [-2.31460345e+02 -1.10666308e-14  0.00000000e+00 ... -1.97655197e-15
#     0.00000000e+00 -1.34373226e-15]
#   [-2.31460345e+02 -1.10666308e-14  0.00000000e+00 ... -1.97655197e-15
#     0.00000000e+00 -1.34373226e-15]
#   ...
#   [-1.41571909e+02  2.99340046e+01 -7.55140388e+00 ... -1.49533692e+00
#    -4.83839652e-01 -1.21278547e+00]
#   [-1.42532086e+02  2.85299256e+01 -7.02029954e+00 ... -1.25255855e+00
#    -1.23433060e-01 -8.53510767e-01]
#   [-1.43108449e+02  2.94642070e+01 -5.78804497e+00 ... -6.01095591e-01
#     4.54038278e-01 -6.47169127e-01]]
#
#  [[-1.94087064e+02  0.00000000e+00 -5.41198678e-15 ...  0.00000000e+00
#    -1.33393494e-15  0.00000000e+00]
#   [-1.94087064e+02  0.00000000e+00 -5.41198678e-15 ...  0.00000000e+00
#    -1.33393494e-15  0.00000000e+00]
#   [-1.94087064e+02  0.00000000e+00 -5.41198678e-15 ...  0.00000000e+00
#    -1.33393494e-15  0.00000000e+00]
#   ...
#   [-5.52562153e+01  8.69360396e+01 -1.20408297e+01 ... -8.42890889e+00
#     3.88172218e-01 -5.05584400e+00]
#   [-5.12331231e+01  8.21348938e+01 -1.13393324e+01 ... -4.14564095e+00
#     1.62546996e-01 -2.57429767e+00]
#   [-4.55185879e+01  7.74935816e+01 -7.05422020e+00 ... -2.71207700e+00
#     5.24141570e-01 -1.64876582e+00]]
#
#  [[-2.16408893e+02  0.00000000e+00 -1.62359603e-14 ...  0.00000000e+00
#    -4.00180481e-15  0.00000000e+00]
#   [-2.16408893e+02  0.00000000e+00 -1.62359603e-14 ...  0.00000000e+00
#    -4.00180481e-15  0.00000000e+00]
#   [-2.16408893e+02  0.00000000e+00 -1.62359603e-14 ...  0.00000000e+00
#    -4.00180481e-15  0.00000000e+00]
#   ...
#   [-1.85828464e+02  3.51476651e+01  2.26020546e+01 ... -2.38747576e+00
#     4.35440592e-01  1.67108060e+00]
#   [-1.82715473e+02  3.91953494e+01  2.38639680e+01 ...  3.78949832e-01
#     9.42160451e-01  3.98245310e-01]
#   [-1.76461777e+02  4.48453316e+01  2.44684542e+01 ...  6.80825342e-01
#     6.48206924e-01  3.21317438e-01]]
#
#  ...
#
#  [[-2.07080420e+02 -1.10666308e-14 -1.08239736e-14 ...  0.00000000e+00
#    -2.66786987e-15 -1.34373226e-15]
#   [-2.07080420e+02 -1.10666308e-14 -1.08239736e-14 ...  0.00000000e+00
#    -2.66786987e-15 -1.34373226e-15]
#   [-2.07080420e+02 -1.10666308e-14 -1.08239736e-14 ...  0.00000000e+00
#    -2.66786987e-15 -1.34373226e-15]
#   ...
#   [-1.31659103e+02  3.46364134e+01 -2.33159144e+01 ... -5.25631181e+00
#    -2.24617134e+00 -2.69654526e+00]
#   [-1.31766746e+02  4.47290808e+01 -1.27215409e+01 ... -4.44041079e+00
#    -1.81700912e+00 -1.72004994e-01]
#   [-1.28743642e+02  4.97716721e+01 -1.09223806e+01 ... -1.74723217e+00
#    -9.93568093e-01 -4.66761873e-01]]
#
#  [[-1.89687584e+02 -1.10666308e-14  0.00000000e+00 ... -1.97655197e-15
#     0.00000000e+00 -1.34373226e-15]
#   [-1.89687584e+02 -1.10666308e-14  0.00000000e+00 ... -1.97655197e-15
#     0.00000000e+00 -1.34373226e-15]
#   [-1.89687584e+02 -1.10666308e-14  0.00000000e+00 ... -1.97655197e-15
#     0.00000000e+00 -1.34373226e-15]
#   ...
#   [-1.87830446e+02  2.26693211e+00  1.30211310e+00 ...  8.02649526e-01
#     9.51393381e-01  6.23453071e-01]
#   [-1.84934675e+02  5.85351754e+00  3.51470778e+00 ...  1.19526659e+00
#     1.69543412e+00  1.16867700e+00]
#   [-1.84205981e+02  6.76117621e+00  4.08951874e+00 ...  1.20908062e+00
#     1.80950343e+00  1.26363837e+00]]
#
#  [[-2.07014205e+02  0.00000000e+00 -1.08239736e-14 ...  0.00000000e+00
#    -2.66786987e-15  0.00000000e+00]
#   [-2.07014205e+02  0.00000000e+00 -1.08239736e-14 ...  0.00000000e+00
#    -2.66786987e-15  0.00000000e+00]
#   [-2.07014205e+02  0.00000000e+00 -1.08239736e-14 ...  0.00000000e+00
#    -2.66786987e-15  0.00000000e+00]
#   ...
#   [-3.27747283e+01  7.35612715e+01 -3.37575670e+01 ... -3.09265752e+00
#     5.38629225e+00  1.41226799e-01]
#   [-4.09396460e+01  6.95871951e+01 -3.24451821e+01 ... -2.57212212e+00
#     7.22008560e+00  3.44665124e+00]
#   [-5.11573729e+01  6.59915818e+01 -2.99547073e+01 ... -1.98267664e+00
#     5.73483514e+00  2.55155571e+00]]]
# [0 0 0 ... 0 0 0]
# (15581, 301, 13)
# (15581,)

# %%
# How many of each class in  oversampled training set.
count0 = 0
count1 = 0
for i in range (oversampled_y_train.shape[0]):
  if oversampled_y_train[i] == 0:
    count0 += 1
  else:
    count1 +=1
print("0: {}, 1: {}".format(count0, count1))
print()
# Out:
# 0: 7384, 1: 8197

# %%
#Replace existing X_train and y_train
X_train = oversampled_X_train
y_train = oversampled_y_train
print(X_train.shape)
print(y_train.shape)
print(X_val.shape)
print(y_val.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (15581, 301, 13)
# (15581,)
# (2281, 301, 13)
# (2281,)
# (1000, 301, 13)
# (1000,)

# %% [markdown]
# Create datasets

# %%
train_dataset = tf.data.Dataset.from_tensor_slices((X_train, y_train))
val_dataset = tf.data.Dataset.from_tensor_slices((X_val, y_val))
test_dataset = tf.data.Dataset.from_tensor_slices((X_test, y_test))

# %%
# Make sure the training data is shuffled when fed into the model

BATCH_SIZE = 100
SHUFFLE_BUFFER_SIZE = 16000 # Needs to be bigger than number of samples in training set

train_dataset = train_dataset.shuffle(SHUFFLE_BUFFER_SIZE).batch(BATCH_SIZE)
val_dataset = val_dataset.batch(BATCH_SIZE)
test_dataset = test_dataset.batch(BATCH_SIZE)

# %% [markdown]
# # RNN-LSTM Network

# %% [markdown]
# Although there are built in measures for precision and recall, there are not the equivalent measures of specificity and negative prediction rate so I have had to create custom metrics for those.
#
# I have used example in (tf.keras.metrics.Metric | TensorFlow Core v2.7.0) for Precision
#  and changed it to calculate the metrics I need.

# %%
# Always run this code.
from keras.utils import metrics_utils
from keras.utils.generic_utils import to_list
from keras import backend
class Specificity(tf.keras.metrics.Metric):
  def __init__(self,
               thresholds=None,
               top_k=None,
               class_id=None,
               name=None,
               dtype=None):
    super(Specificity, self).__init__(name=name, dtype=dtype)
    self.init_thresholds = thresholds
    self.top_k = top_k
    self.class_id = class_id

    default_threshold = 0.5 if top_k is None else metrics_utils.NEG_INF
    self.thresholds = metrics_utils.parse_init_thresholds(
        thresholds, default_threshold=default_threshold)
    self._thresholds_distributed_evenly = (
        metrics_utils.is_evenly_distributed_thresholds(self.thresholds))
    self.true_negatives = self.add_weight(
        'true_negatives',
        shape=(len(self.thresholds),),
        initializer=tf.compat.v1.zeros_initializer)
    self.false_positives = self.add_weight(
        'false_positives',
        shape=(len(self.thresholds),),
        initializer=tf.compat.v1.zeros_initializer)

  def update_state(self, y_true, y_pred, sample_weight=None):
    """Accumulates true positive and false positive statistics.
    Args:
      y_true: The ground truth values, with the same dimensions as `y_pred`.
        Will be cast to `bool`.
      y_pred: The predicted values. Each element must be in the range `[0, 1]`.
      sample_weight: Optional weighting of each example. Defaults to 1. Can be a
        `Tensor` whose rank is either 0, or the same rank as `y_true`, and must
        be broadcastable to `y_true`.
    Returns:
      Update op.
    """
    return metrics_utils.update_confusion_matrix_variables(
        {
            metrics_utils.ConfusionMatrix.TRUE_NEGATIVES: self.true_negatives,
            metrics_utils.ConfusionMatrix.FALSE_POSITIVES: self.false_positives
        },
        y_true,
        y_pred,
        thresholds=self.thresholds,
        thresholds_distributed_evenly=self._thresholds_distributed_evenly,
        top_k=self.top_k,
        class_id=self.class_id,
        sample_weight=sample_weight)

  def result(self):
    result = tf.math.divide_no_nan(
        self.true_negatives,
        tf.math.add(self.true_negatives, self.false_positives))
    return result[0] if len(self.thresholds) == 1 else result

  def reset_state(self):
    num_thresholds = len(to_list(self.thresholds))
    backend.batch_set_value([(v, np.zeros((num_thresholds,)))
                             for v in (self.true_negatives,
                                       self.false_positives)])

  def get_config(self):
    config = {
        'thresholds': self.init_thresholds,
        'top_k': self.top_k,
        'class_id': self.class_id
    }
    base_config = super(Specificity, self).get_config()
    return dict(list(base_config.items()) + list(config.items()))

# %%
# Always run this code.
from keras.utils import metrics_utils
from keras.utils.generic_utils import to_list
from keras import backend
class NPV(tf.keras.metrics.Metric):
  def __init__(self,
               thresholds=None,
               top_k=None,
               class_id=None,
               name=None,
               dtype=None):
    super(NPV, self).__init__(name=name, dtype=dtype)
    self.init_thresholds = thresholds
    self.top_k = top_k
    self.class_id = class_id

    default_threshold = 0.5 if top_k is None else metrics_utils.NEG_INF
    self.thresholds = metrics_utils.parse_init_thresholds(
        thresholds, default_threshold=default_threshold)
    self._thresholds_distributed_evenly = (
        metrics_utils.is_evenly_distributed_thresholds(self.thresholds))
    self.true_negatives = self.add_weight(
        'true_negatives',
        shape=(len(self.thresholds),),
        initializer=tf.compat.v1.zeros_initializer)
    self.false_negatives = self.add_weight(
        'false_negatives',
        shape=(len(self.thresholds),),
        initializer=tf.compat.v1.zeros_initializer)

  def update_state(self, y_true, y_pred, sample_weight=None):
    """Accumulates true positive and false positive statistics.
    Args:
      y_true: The ground truth values, with the same dimensions as `y_pred`.
        Will be cast to `bool`.
      y_pred: The predicted values. Each element must be in the range `[0, 1]`.
      sample_weight: Optional weighting of each example. Defaults to 1. Can be a
        `Tensor` whose rank is either 0, or the same rank as `y_true`, and must
        be broadcastable to `y_true`.
    Returns:
      Update op.
    """
    return metrics_utils.update_confusion_matrix_variables(
        {
            metrics_utils.ConfusionMatrix.TRUE_NEGATIVES: self.true_negatives,
            metrics_utils.ConfusionMatrix.FALSE_NEGATIVES: self.false_negatives
        },
        y_true,
        y_pred,
        thresholds=self.thresholds,
        thresholds_distributed_evenly=self._thresholds_distributed_evenly,
        top_k=self.top_k,
        class_id=self.class_id,
        sample_weight=sample_weight)

  def result(self):
    result = tf.math.divide_no_nan(
        self.true_negatives,
        tf.math.add(self.true_negatives, self.false_negatives))
    return result[0] if len(self.thresholds) == 1 else result

  def reset_state(self):
    num_thresholds = len(to_list(self.thresholds))
    backend.batch_set_value([(v, np.zeros((num_thresholds,)))
                             for v in (self.true_negatives,
                                       self.false_negatives)])

  def get_config(self):
    config = {
        'thresholds': self.init_thresholds,
        'top_k': self.top_k,
        'class_id': self.class_id
    }
    base_config = super(NPV, self).get_config()
    return dict(list(base_config.items()) + list(config.items()))

# %% [markdown]
# # **Metrics available for use**

# %%
# Always run this cell.
precision = tf.keras.metrics.Precision(name = "precision")
recall = tf.keras.metrics.Recall(name = "recall")
specificity = Specificity(name = "specificity")
TP = tf.keras.metrics.TruePositives(name = "TP") 
FP = tf.keras.metrics.FalsePositives(name = "FP")
FN = tf.keras.metrics.FalseNegatives(name = "FN")
TN = tf.keras.metrics.TrueNegatives(name = "TN")
auc = tf.keras.metrics.AUC(name = "auc")
npv = NPV(name = "NPV")

# %% [markdown]
# # **Fit model on the training dataset**

# %%
#Run this cell to create model or use next cell to load existing model.
model_name = "Covid_Model_l3.h5" #Change name here for each new model

INPUT_SHAPE = (X_train.shape[1], X_train.shape[2])

model = keras.Sequential([              
   
    # LSTM layers
    layers.LSTM(64, input_shape=INPUT_SHAPE, return_sequences=True),
    layers.LSTM(64, input_shape=INPUT_SHAPE, return_sequences=True),
    layers.LSTM(64),
    
    # Head
    layers.Dense(64, activation='relu'),
    layers.Dropout(0.3),
    layers.Dense(1, activation='sigmoid')
])

model._name= model_name[:-3]

model_plots_folder = os.path.join(folder,'model_plots')

# Save model summaries to a text file.
with open(os.path.join(model_plots_folder,'Model_summaries.txt'), 'a') as f:
    with redirect_stdout(f):
        model.summary()

# Save model plots to individual png files.
plot_model(
    model,
    to_file=(os.path.join(model_plots_folder, model_name[:-3] + ".png")),
    show_shapes=True,
    show_dtype=False,
    show_layer_names=True,
    rankdir="TB",
    expand_nested=False,
    dpi=96,
    layer_range=None,
    show_layer_activations=False,
)

model.summary()
plot_model(model, show_shapes=True)

es_callback = EarlyStopping(monitor = 'val_auc',
                            mode='max',
                            min_delta = 0.01,
                            patience = 10,
                            restore_best_weights = True)

model.compile(
    optimizer=tf.keras.optimizers.Adam(epsilon=0.01),
    loss='binary_crossentropy',
    metrics=[TP, FP, FN, TN, 
             npv, specificity, 
             recall, auc
             ]
)

model_folder = '/content/drive/My Drive/Colab Notebooks/models/'

history = model.fit(
    train_dataset,
    validation_data=val_dataset,
    callbacks = [es_callback],
    epochs = 30
    )

model.save(model_folder + model_name)
# Out:
# Model: "Covid_Model_l3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 301, 64)           19968
#
#  lstm_1 (LSTM)               (None, 301, 64)           33024
#
#  lstm_2 (LSTM)               (None, 64)                33024
#
#  dense (Dense)               (None, 64)                4160
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense_1 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 90,241
# Trainable params: 90,241
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 156/156 [==============================] - 21s 61ms/step - loss: 0.6921 - TP: 6916.0000 - FP: 6210.0000 - FN: 1281.0000 - TN: 1174.0000 - NPV: 0.4782 - specificity: 0.1590 - recall: 0.8437 - auc: 0.5077 - val_loss: 0.6327 - val_TP: 2041.0000 - val_FP: 229.0000 - val_FN: 10.0000 - val_TN: 1.0000 - val_NPV: 0.0909 - val_specificity: 0.0043 - val_recall: 0.9951 - val_auc: 0.5097
# Epoch 2/30
# 156/156 [==============================] - 8s 51ms/step - loss: 0.6883 - TP: 6898.0000 - FP: 5803.0000 - FN: 1299.0000 - TN: 1581.0000 - NPV: 0.5490 - specificity: 0.2141 - recall: 0.8415 - auc: 0.5523 - val_loss: 0.6492 - val_TP: 1688.0000 - val_FP: 185.0000 - val_FN: 363.0000 - val_TN: 45.0000 - val_NPV: 0.1103 - val_specificity: 0.1957 - val_recall: 0.8230 - val_auc: 0.5448
# Epoch 3/30
# 156/156 [==============================] - 8s 51ms/step - loss: 0.6809 - TP: 5878.0000 - FP: 4490.0000 - FN: 2319.0000 - TN: 2894.0000 - NPV: 0.5552 - specificity: 0.3919 - recall: 0.7171 - auc: 0.5894 - val_loss: 0.6473 - val_TP: 1193.0000 - val_FP: 116.0000 - val_FN: 858.0000 - val_TN: 114.0000 - val_NPV: 0.1173 - val_specificity: 0.4957 - val_recall: 0.5817 - val_auc: 0.5521
# Epoch 4/30
# 156/156 [==============================] - 8s 51ms/step - loss: 0.6710 - TP: 4836.0000 - FP: 3223.0000 - FN: 3361.0000 - TN: 4161.0000 - NPV: 0.5532 - specificity: 0.5635 - recall: 0.5900 - auc: 0.6139 - val_loss: 0.6040 - val_TP: 1415.0000 - val_FP: 133.0000 - val_FN: 636.0000 - val_TN: 97.0000 - val_NPV: 0.1323 - val_specificity: 0.4217 - val_recall: 0.6899 - val_auc: 0.5889
# Epoch 5/30
# 156/156 [==============================] - 8s 51ms/step - loss: 0.6641 - TP: 4968.0000 - FP: 3178.0000 - FN: 3229.0000 - TN: 4206.0000 - NPV: 0.5657 - specificity: 0.5696 - recall: 0.6061 - auc: 0.6305 - val_loss: 0.5438 - val_TP: 1851.0000 - val_FP: 184.0000 - val_FN: 200.0000 - val_TN: 46.0000 - val_NPV: 0.1870 - val_specificity: 0.2000 - val_recall: 0.9025 - val_auc: 0.5930
# Epoch 6/30
# 156/156 [==============================] - 8s 51ms/step - loss: 0.6572 - TP: 5131.0000 - FP: 3210.0000 - FN: 3066.0000 - TN: 4174.0000 - NPV: 0.5765 - specificity: 0.5653 - recall: 0.6260 - auc: 0.6450 - val_loss: 0.5586 - val_TP: 1660.0000 - val_FP: 161.0000 - val_FN: 391.0000 - val_TN: 69.0000 - val_NPV: 0.1500 - val_specificity: 0.3000 - val_recall: 0.8094 - val_auc: 0.5944
# Epoch 7/30
# 156/156 [==============================] - 8s 51ms/step - loss: 0.6493 - TP: 5215.0000 - FP: 3110.0000 - FN: 2982.0000 - TN: 4274.0000 - NPV: 0.5890 - specificity: 0.5788 - recall: 0.6362 - auc: 0.6602 - val_loss: 0.5661 - val_TP: 1717.0000 - val_FP: 174.0000 - val_FN: 334.0000 - val_TN: 56.0000 - val_NPV: 0.1436 - val_specificity: 0.2435 - val_recall: 0.8372 - val_auc: 0.5856
# Epoch 8/30
# 156/156 [==============================] - 8s 50ms/step - loss: 0.6418 - TP: 5343.0000 - FP: 2947.0000 - FN: 2854.0000 - TN: 4437.0000 - NPV: 0.6086 - specificity: 0.6009 - recall: 0.6518 - auc: 0.6769 - val_loss: 0.6144 - val_TP: 1258.0000 - val_FP: 112.0000 - val_FN: 793.0000 - val_TN: 118.0000 - val_NPV: 0.1295 - val_specificity: 0.5130 - val_recall: 0.6134 - val_auc: 0.5909
# Epoch 9/30
# 156/156 [==============================] - 8s 51ms/step - loss: 0.6393 - TP: 5284.0000 - FP: 3013.0000 - FN: 2913.0000 - TN: 4371.0000 - NPV: 0.6001 - specificity: 0.5920 - recall: 0.6446 - auc: 0.6769 - val_loss: 0.7340 - val_TP: 856.0000 - val_FP: 63.0000 - val_FN: 1195.0000 - val_TN: 167.0000 - val_NPV: 0.1226 - val_specificity: 0.7261 - val_recall: 0.4174 - val_auc: 0.6018
# Epoch 10/30
# 156/156 [==============================] - 8s 49ms/step - loss: 0.6257 - TP: 5508.0000 - FP: 2991.0000 - FN: 2689.0000 - TN: 4393.0000 - NPV: 0.6203 - specificity: 0.5949 - recall: 0.6720 - auc: 0.6983 - val_loss: 0.5644 - val_TP: 1324.0000 - val_FP: 127.0000 - val_FN: 727.0000 - val_TN: 103.0000 - val_NPV: 0.1241 - val_specificity: 0.4478 - val_recall: 0.6455 - val_auc: 0.5772
# Epoch 11/30
# 156/156 [==============================] - 9s 54ms/step - loss: 0.6231 - TP: 5471.0000 - FP: 2885.0000 - FN: 2726.0000 - TN: 4499.0000 - NPV: 0.6227 - specificity: 0.6093 - recall: 0.6674 - auc: 0.7033 - val_loss: 0.5682 - val_TP: 1594.0000 - val_FP: 159.0000 - val_FN: 457.0000 - val_TN: 71.0000 - val_NPV: 0.1345 - val_specificity: 0.3087 - val_recall: 0.7772 - val_auc: 0.5946
# Epoch 12/30
# 156/156 [==============================] - 8s 50ms/step - loss: 0.6095 - TP: 5653.0000 - FP: 2881.0000 - FN: 2544.0000 - TN: 4503.0000 - NPV: 0.6390 - specificity: 0.6098 - recall: 0.6896 - auc: 0.7209 - val_loss: 0.6889 - val_TP: 1223.0000 - val_FP: 107.0000 - val_FN: 828.0000 - val_TN: 123.0000 - val_NPV: 0.1293 - val_specificity: 0.5348 - val_recall: 0.5963 - val_auc: 0.5994
# Epoch 13/30
# 156/156 [==============================] - 8s 51ms/step - loss: 0.6019 - TP: 5827.0000 - FP: 2886.0000 - FN: 2370.0000 - TN: 4498.0000 - NPV: 0.6549 - specificity: 0.6092 - recall: 0.7109 - auc: 0.7298 - val_loss: 0.6229 - val_TP: 1352.0000 - val_FP: 126.0000 - val_FN: 699.0000 - val_TN: 104.0000 - val_NPV: 0.1295 - val_specificity: 0.4522 - val_recall: 0.6592 - val_auc: 0.5957
# Epoch 14/30
# 156/156 [==============================] - 8s 51ms/step - loss: 0.5945 - TP: 5992.0000 - FP: 2981.0000 - FN: 2205.0000 - TN: 4403.0000 - NPV: 0.6663 - specificity: 0.5963 - recall: 0.7310 - auc: 0.7386 - val_loss: 0.6684 - val_TP: 1120.0000 - val_FP: 89.0000 - val_FN: 931.0000 - val_TN: 141.0000 - val_NPV: 0.1315 - val_specificity: 0.6130 - val_recall: 0.5461 - val_auc: 0.6151
# Epoch 15/30
# 156/156 [==============================] - 8s 51ms/step - loss: 0.5878 - TP: 5716.0000 - FP: 2716.0000 - FN: 2481.0000 - TN: 4668.0000 - NPV: 0.6530 - specificity: 0.6322 - recall: 0.6973 - auc: 0.7446 - val_loss: 0.6558 - val_TP: 1281.0000 - val_FP: 110.0000 - val_FN: 770.0000 - val_TN: 120.0000 - val_NPV: 0.1348 - val_specificity: 0.5217 - val_recall: 0.6246 - val_auc: 0.6081
# Epoch 16/30
# 156/156 [==============================] - 8s 52ms/step - loss: 0.5760 - TP: 5733.0000 - FP: 2510.0000 - FN: 2464.0000 - TN: 4874.0000 - NPV: 0.6642 - specificity: 0.6601 - recall: 0.6994 - auc: 0.7574 - val_loss: 0.6295 - val_TP: 1335.0000 - val_FP: 119.0000 - val_FN: 716.0000 - val_TN: 111.0000 - val_NPV: 0.1342 - val_specificity: 0.4826 - val_recall: 0.6509 - val_auc: 0.5971
# Epoch 17/30
# 156/156 [==============================] - 8s 52ms/step - loss: 0.5717 - TP: 5726.0000 - FP: 2534.0000 - FN: 2471.0000 - TN: 4850.0000 - NPV: 0.6625 - specificity: 0.6568 - recall: 0.6985 - auc: 0.7605 - val_loss: 0.6502 - val_TP: 1149.0000 - val_FP: 105.0000 - val_FN: 902.0000 - val_TN: 125.0000 - val_NPV: 0.1217 - val_specificity: 0.5435 - val_recall: 0.5602 - val_auc: 0.5918
# Epoch 18/30
# 156/156 [==============================] - 8s 51ms/step - loss: 0.5553 - TP: 5853.0000 - FP: 2344.0000 - FN: 2344.0000 - TN: 5040.0000 - NPV: 0.6826 - specificity: 0.6826 - recall: 0.7140 - auc: 0.7792 - val_loss: 0.6331 - val_TP: 1315.0000 - val_FP: 118.0000 - val_FN: 736.0000 - val_TN: 112.0000 - val_NPV: 0.1321 - val_specificity: 0.4870 - val_recall: 0.6412 - val_auc: 0.5997
# Epoch 19/30
# 156/156 [==============================] - 8s 51ms/step - loss: 0.5452 - TP: 5862.0000 - FP: 2379.0000 - FN: 2335.0000 - TN: 5005.0000 - NPV: 0.6819 - specificity: 0.6778 - recall: 0.7151 - auc: 0.7845 - val_loss: 0.6675 - val_TP: 1269.0000 - val_FP: 122.0000 - val_FN: 782.0000 - val_TN: 108.0000 - val_NPV: 0.1213 - val_specificity: 0.4696 - val_recall: 0.6187 - val_auc: 0.5822
# Epoch 20/30
# 156/156 [==============================] - 8s 51ms/step - loss: 0.5381 - TP: 5593.0000 - FP: 2035.0000 - FN: 2604.0000 - TN: 5349.0000 - NPV: 0.6726 - specificity: 0.7244 - recall: 0.6823 - auc: 0.7918 - val_loss: 0.6045 - val_TP: 1548.0000 - val_FP: 150.0000 - val_FN: 503.0000 - val_TN: 80.0000 - val_NPV: 0.1372 - val_specificity: 0.3478 - val_recall: 0.7548 - val_auc: 0.5861
# Epoch 21/30
# 156/156 [==============================] - 8s 52ms/step - loss: 0.5258 - TP: 5952.0000 - FP: 2194.0000 - FN: 2245.0000 - TN: 5190.0000 - NPV: 0.6980 - specificity: 0.7029 - recall: 0.7261 - auc: 0.8033 - val_loss: 0.6315 - val_TP: 1339.0000 - val_FP: 116.0000 - val_FN: 712.0000 - val_TN: 114.0000 - val_NPV: 0.1380 - val_specificity: 0.4957 - val_recall: 0.6529 - val_auc: 0.6042
# Epoch 22/30
# 156/156 [==============================] - 8s 51ms/step - loss: 0.5100 - TP: 5906.0000 - FP: 2002.0000 - FN: 2291.0000 - TN: 5382.0000 - NPV: 0.7014 - specificity: 0.7289 - recall: 0.7205 - auc: 0.8162 - val_loss: 0.6660 - val_TP: 1351.0000 - val_FP: 123.0000 - val_FN: 700.0000 - val_TN: 107.0000 - val_NPV: 0.1326 - val_specificity: 0.4652 - val_recall: 0.6587 - val_auc: 0.5948
# Epoch 23/30
# 156/156 [==============================] - 8s 52ms/step - loss: 0.4975 - TP: 5966.0000 - FP: 1869.0000 - FN: 2231.0000 - TN: 5515.0000 - NPV: 0.7120 - specificity: 0.7469 - recall: 0.7278 - auc: 0.8275 - val_loss: 0.6174 - val_TP: 1495.0000 - val_FP: 136.0000 - val_FN: 556.0000 - val_TN: 94.0000 - val_NPV: 0.1446 - val_specificity: 0.4087 - val_recall: 0.7289 - val_auc: 0.5859
# Epoch 24/30
# 156/156 [==============================] - 8s 51ms/step - loss: 0.4893 - TP: 5936.0000 - FP: 1756.0000 - FN: 2261.0000 - TN: 5628.0000 - NPV: 0.7134 - specificity: 0.7622 - recall: 0.7242 - auc: 0.8337 - val_loss: 0.5393 - val_TP: 1597.0000 - val_FP: 153.0000 - val_FN: 454.0000 - val_TN: 77.0000 - val_NPV: 0.1450 - val_specificity: 0.3348 - val_recall: 0.7786 - val_auc: 0.5770

# %%
#Only run this cell if you want to reload model run previously.
model_folder = '/content/drive/My Drive/Colab Notebooks/models/'

custom_objects = {"NPV": NPV, "Specificity": Specificity}
with keras.utils.custom_object_scope(custom_objects):
    model = tf.keras.models.load_model(model_folder + "Covid_Model_l3.h5")

# %% [markdown]
# # **Apply model to test dataset.**

# %%
_,TP,FP,FN,TN, Spec, npv, Recall, AUC = model.evaluate(test_dataset)
print('Confusion Matrix: ', TP, FP, FN, TN)
print('Test NPV: %.4f' % npv)
print('Test Specificity: %.4f' % Spec)
print('Test Recall: %.4f' % Recall)
print('Test ROC-AUC: %.4f' % AUC)
# Out:
# 10/10 [==============================] - 0s 22ms/step - loss: 0.6744 - TP: 486.0000 - FP: 53.0000 - FN: 400.0000 - TN: 61.0000 - NPV: 0.1323 - specificity: 0.5351 - recall: 0.5485 - auc: 0.5920
# Confusion Matrix:  486.0 53.0 400.0 61.0
# Test NPV: 0.5351
# Test Specificity: 0.1323
# Test Recall: 0.5485
# Test ROC-AUC: 0.5920

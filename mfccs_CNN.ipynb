# %% [markdown]
# Using a dataset of mfccs with a CNN model.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import warnings
warnings.simplefilter("ignore")
import os
import numpy as np
import matplotlib.pyplot as plt
import math
import json
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.utils import plot_model
from contextlib import redirect_stdout
import numpy as np
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras import optimizers
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_curve

# %%
folder = '/content/drive/My Drive/Colab Notebooks/COVID-19'
if not os.path.exists(folder):
  print(folder + ' does not exist')

mfcc_folder = os.path.join(folder, 'mfcc_json_files')
if not os.path.exists(mfcc_folder):
  print(mfcc_folder + ' does not exist')

# %% [markdown]
# Read in json files created previously in Extract_rawMFCCs.ipynb.

# %%
def load_jsonfile(path, filename):
  with open(os.path.join(path, filename)) as json_file:
    data = json.load(json_file)
  print("{} loaded".format(filename))
  return data

# %%
test_data = load_jsonfile(mfcc_folder, 'test_mfccs.json')
train_data = load_jsonfile(mfcc_folder, 'train_mfccs.json')
# Out:
# test_mfccs.json loaded
# train_mfccs.json loaded

# %% [markdown]
# Change labels to 0s and 1s

# %%
test_data_labels = []
for i in range (len(test_data["labels"])):
  if test_data["labels"][i] == 'healthy':
    test_data_labels.append(1)
  else:
    test_data_labels.append(0)

train_data_labels = []
for i in range (len(train_data["labels"])):
  if train_data["labels"][i] == 'healthy':
    train_data_labels.append(1)
  else:
    train_data_labels.append(0)

# %% [markdown]
# Create X_train, y_train, X_test, y_test

# %%
# Test data
X_test = np.array(test_data["mfcc"])
y_test = np.array(test_data_labels)

# Train data
X_train = np.array(train_data["mfcc"])
y_train = np.array(train_data_labels)

print("X_train shape: {}, y_train shape: {}, X_test shape: {}, y_test shape: {}".format(
    X_train.shape, y_train.shape, X_test.shape, y_test.shape))
# Out:
# X_train shape: (11401, 301, 13), y_train shape: (11401,), X_test shape: (1000, 301, 13), y_test shape: (1000,)

# %% [markdown]
# Split out a validation set

# %%
validation_size = 0.2
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=validation_size)

# %% [markdown]
# Check shape of X_train, y_train, X_val, y_val, X_test and y_test

# %%
print(X_train.shape)
print(y_train.shape)
print(X_val.shape)
print(y_val.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (9120, 301, 13)
# (9120,)
# (2281, 301, 13)
# (2281,)
# (1000, 301, 13)
# (1000,)

# %%
# Change to 3D ready to feed into CNN
X_train = X_train[..., np.newaxis]
X_val = X_val[..., np.newaxis]
X_test = X_test[..., np.newaxis]

# %%
print(X_train.shape)
print(y_train.shape)
print(X_val.shape)
print(y_val.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (9120, 301, 13, 1)
# (9120,)
# (2281, 301, 13, 1)
# (2281,)
# (1000, 301, 13, 1)
# (1000,)

# %% [markdown]
# Create datasets

# %%
train_dataset = tf.data.Dataset.from_tensor_slices((X_train, y_train))
val_dataset = tf.data.Dataset.from_tensor_slices((X_val, y_val))
test_dataset = tf.data.Dataset.from_tensor_slices((X_test, y_test))

# %%
# Make sure the training data is shuffled when fed into the model

BATCH_SIZE = 100
SHUFFLE_BUFFER_SIZE = 10000 # Needs to be bigger than number of samples in trining set

train_dataset = train_dataset.shuffle(SHUFFLE_BUFFER_SIZE).batch(BATCH_SIZE)
val_dataset = val_dataset.batch(BATCH_SIZE)
test_dataset = test_dataset.batch(BATCH_SIZE)

# %% [markdown]
# # CNN Network

# %% [markdown]
# Although there are built in measures for precision and recall, there are not the equivalent measures of specificity and negative prediction rate so I have had to create custom metrics for those.
#
# I have used example in (tf.keras.metrics.Metric | TensorFlow Core v2.7.0) for Precision
#  and changed it to calculate the metrics I need.

# %%
# Always run this code.
from keras.utils import metrics_utils
from keras.utils.generic_utils import to_list
from keras import backend
class Specificity(tf.keras.metrics.Metric):
  def __init__(self,
               thresholds=None,
               top_k=None,
               class_id=None,
               name=None,
               dtype=None):
    super(Specificity, self).__init__(name=name, dtype=dtype)
    self.init_thresholds = thresholds
    self.top_k = top_k
    self.class_id = class_id

    default_threshold = 0.5 if top_k is None else metrics_utils.NEG_INF
    self.thresholds = metrics_utils.parse_init_thresholds(
        thresholds, default_threshold=default_threshold)
    self._thresholds_distributed_evenly = (
        metrics_utils.is_evenly_distributed_thresholds(self.thresholds))
    self.true_negatives = self.add_weight(
        'true_negatives',
        shape=(len(self.thresholds),),
        initializer=tf.compat.v1.zeros_initializer)
    self.false_positives = self.add_weight(
        'false_positives',
        shape=(len(self.thresholds),),
        initializer=tf.compat.v1.zeros_initializer)

  def update_state(self, y_true, y_pred, sample_weight=None):
    """Accumulates true positive and false positive statistics.
    Args:
      y_true: The ground truth values, with the same dimensions as `y_pred`.
        Will be cast to `bool`.
      y_pred: The predicted values. Each element must be in the range `[0, 1]`.
      sample_weight: Optional weighting of each example. Defaults to 1. Can be a
        `Tensor` whose rank is either 0, or the same rank as `y_true`, and must
        be broadcastable to `y_true`.
    Returns:
      Update op.
    """
    return metrics_utils.update_confusion_matrix_variables(
        {
            metrics_utils.ConfusionMatrix.TRUE_NEGATIVES: self.true_negatives,
            metrics_utils.ConfusionMatrix.FALSE_POSITIVES: self.false_positives
        },
        y_true,
        y_pred,
        thresholds=self.thresholds,
        thresholds_distributed_evenly=self._thresholds_distributed_evenly,
        top_k=self.top_k,
        class_id=self.class_id,
        sample_weight=sample_weight)

  def result(self):
    result = tf.math.divide_no_nan(
        self.true_negatives,
        tf.math.add(self.true_negatives, self.false_positives))
    return result[0] if len(self.thresholds) == 1 else result

  def reset_state(self):
    num_thresholds = len(to_list(self.thresholds))
    backend.batch_set_value([(v, np.zeros((num_thresholds,)))
                             for v in (self.true_negatives,
                                       self.false_positives)])

  def get_config(self):
    config = {
        'thresholds': self.init_thresholds,
        'top_k': self.top_k,
        'class_id': self.class_id
    }
    base_config = super(Specificity, self).get_config()
    return dict(list(base_config.items()) + list(config.items()))

# %%
# Always run this code.
from keras.utils import metrics_utils
from keras.utils.generic_utils import to_list
from keras import backend
class NPV(tf.keras.metrics.Metric):
  def __init__(self,
               thresholds=None,
               top_k=None,
               class_id=None,
               name=None,
               dtype=None):
    super(NPV, self).__init__(name=name, dtype=dtype)
    self.init_thresholds = thresholds
    self.top_k = top_k
    self.class_id = class_id

    default_threshold = 0.5 if top_k is None else metrics_utils.NEG_INF
    self.thresholds = metrics_utils.parse_init_thresholds(
        thresholds, default_threshold=default_threshold)
    self._thresholds_distributed_evenly = (
        metrics_utils.is_evenly_distributed_thresholds(self.thresholds))
    self.true_negatives = self.add_weight(
        'true_negatives',
        shape=(len(self.thresholds),),
        initializer=tf.compat.v1.zeros_initializer)
    self.false_negatives = self.add_weight(
        'false_negatives',
        shape=(len(self.thresholds),),
        initializer=tf.compat.v1.zeros_initializer)

  def update_state(self, y_true, y_pred, sample_weight=None):
    """Accumulates true positive and false positive statistics.
    Args:
      y_true: The ground truth values, with the same dimensions as `y_pred`.
        Will be cast to `bool`.
      y_pred: The predicted values. Each element must be in the range `[0, 1]`.
      sample_weight: Optional weighting of each example. Defaults to 1. Can be a
        `Tensor` whose rank is either 0, or the same rank as `y_true`, and must
        be broadcastable to `y_true`.
    Returns:
      Update op.
    """
    return metrics_utils.update_confusion_matrix_variables(
        {
            metrics_utils.ConfusionMatrix.TRUE_NEGATIVES: self.true_negatives,
            metrics_utils.ConfusionMatrix.FALSE_NEGATIVES: self.false_negatives
        },
        y_true,
        y_pred,
        thresholds=self.thresholds,
        thresholds_distributed_evenly=self._thresholds_distributed_evenly,
        top_k=self.top_k,
        class_id=self.class_id,
        sample_weight=sample_weight)

  def result(self):
    result = tf.math.divide_no_nan(
        self.true_negatives,
        tf.math.add(self.true_negatives, self.false_negatives))
    return result[0] if len(self.thresholds) == 1 else result

  def reset_state(self):
    num_thresholds = len(to_list(self.thresholds))
    backend.batch_set_value([(v, np.zeros((num_thresholds,)))
                             for v in (self.true_negatives,
                                       self.false_negatives)])

  def get_config(self):
    config = {
        'thresholds': self.init_thresholds,
        'top_k': self.top_k,
        'class_id': self.class_id
    }
    base_config = super(NPV, self).get_config()
    return dict(list(base_config.items()) + list(config.items()))

# %% [markdown]
# # **Metrics available for use**

# %%
# Always run this cell.
precision = tf.keras.metrics.Precision(name = "precision")
recall = tf.keras.metrics.Recall(name = "recall")
specificity = Specificity(name = "specificity")
TP = tf.keras.metrics.TruePositives(name = "TP") 
FP = tf.keras.metrics.FalsePositives(name = "FP")
FN = tf.keras.metrics.FalseNegatives(name = "FN")
TN = tf.keras.metrics.TrueNegatives(name = "TN")
auc = tf.keras.metrics.AUC(name = "auc")
npv = NPV(name = "NPV")

# %% [markdown]
# # **Fit model on the training dataset**

# %%
#Run this cell to create model or use next cell to load existing model.
model_name = "Covid_Model_m1.h5" #Change name here for each new model

INPUT_SHAPE = (X_train.shape[1], X_train.shape[2], 1)

model = keras.Sequential([              
   
    # Block One
    layers.Conv2D(filters=32, kernel_size=3, activation='relu', padding='same',
                  input_shape = INPUT_SHAPE),
    layers.MaxPool2D((3, 3), strides=(2, 2), padding='same'),
    layers.BatchNormalization(),

    # Block Two
    layers.Conv2D(filters=32, kernel_size=3, activation='relu', padding='same'),
    layers.MaxPool2D((3, 3), strides=(2, 2), padding='same'),
    layers.BatchNormalization(),

    # Block Three
    layers.Conv2D(filters=32, kernel_size=3, activation='relu', padding='same'),
    layers.MaxPool2D((3, 3), strides=(2, 2), padding='same'),
    layers.BatchNormalization(),

    # Block Four
    layers.Conv2D(filters=32, kernel_size=3, activation='relu', padding='same'),
    layers.MaxPool2D((3, 3), strides=(2, 2), padding='same'),
    layers.BatchNormalization(),

    # Block Five
    layers.Conv2D(filters=32, kernel_size=3, activation='relu', padding='same'),
    layers.MaxPool2D((3, 3), strides=(2, 2), padding='same'),
    layers.BatchNormalization(),

    # Head
    layers.Flatten(),
    layers.Dropout(0.25),
    layers.Dense(128, activation='relu'),
    layers.Dropout(0.25),
    layers.Dense(1, activation='sigmoid'),
])

model._name= model_name[:-3]

model_plots_folder = os.path.join(folder,'model_plots')

# Save model summaries to a text file.
with open(os.path.join(model_plots_folder,'Model_summaries.txt'), 'a') as f:
    with redirect_stdout(f):
        model.summary()

# Save model plots to individual png files.
plot_model(
    model,
    to_file=(os.path.join(model_plots_folder, model_name[:-3] + ".png")),
    show_shapes=True,
    show_dtype=False,
    show_layer_names=True,
    rankdir="TB",
    expand_nested=False,
    dpi=96,
    layer_range=None,
    show_layer_activations=False,
)

model.summary()
plot_model(model, show_shapes=True)

es_callback = EarlyStopping(monitor = 'val_auc',
                            mode='max',
                            min_delta = 0.01,
                            patience = 10,
                            restore_best_weights = True)

model.compile(
    optimizer=tf.keras.optimizers.Adam(epsilon=0.01),
    loss='binary_crossentropy',
    metrics=[TP, FP, FN, TN, 
             npv, specificity, 
             recall, auc
             ]
)

model_folder = '/content/drive/My Drive/Colab Notebooks/models/'

history = model.fit(
    train_dataset,
    validation_data=val_dataset,
    callbacks = [es_callback],
    epochs = 30,
    #steps_per_epoch=len(train_dataset) // BATCH_SIZE,
    #validation_steps=len(val_dataset) // BATCH_SIZE
    )

model.save(model_folder + model_name)
# Out:
# Model: "Covid_Model_m1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_55 (Conv2D)          (None, 301, 13, 32)       320
#
#  max_pooling2d_55 (MaxPoolin  (None, 151, 7, 32)       0
#  g2D)
#
#  batch_normalization_55 (Bat  (None, 151, 7, 32)       128
#  chNormalization)
#
#  conv2d_56 (Conv2D)          (None, 151, 7, 32)        9248
#
#  max_pooling2d_56 (MaxPoolin  (None, 76, 4, 32)        0
#  g2D)
#
#  batch_normalization_56 (Bat  (None, 76, 4, 32)        128
#  chNormalization)
#
#  conv2d_57 (Conv2D)          (None, 76, 4, 32)         9248
#
#  max_pooling2d_57 (MaxPoolin  (None, 38, 2, 32)        0
#  g2D)
#
#  batch_normalization_57 (Bat  (None, 38, 2, 32)        128
#  chNormalization)
#
#  conv2d_58 (Conv2D)          (None, 38, 2, 32)         9248
#
#  max_pooling2d_58 (MaxPoolin  (None, 19, 1, 32)        0
#  g2D)
#
#  batch_normalization_58 (Bat  (None, 19, 1, 32)        128
#  chNormalization)
#
#  conv2d_59 (Conv2D)          (None, 19, 1, 32)         9248
#
#  max_pooling2d_59 (MaxPoolin  (None, 10, 1, 32)        0
#  g2D)
#
#  batch_normalization_59 (Bat  (None, 10, 1, 32)        128
#  chNormalization)
#
#  flatten_11 (Flatten)        (None, 320)               0
#
#  dropout_22 (Dropout)        (None, 320)               0
#
#  dense_22 (Dense)            (None, 128)               41088
#
#  dropout_23 (Dropout)        (None, 128)               0
#
#  dense_23 (Dense)            (None, 1)                 129
#
# =================================================================
# Total params: 79,169
# Trainable params: 78,849
# Non-trainable params: 320
# _________________________________________________________________
# Epoch 1/30
# 92/92 [==============================] - 4s 23ms/step - loss: 0.3975 - TP: 7835.0000 - FP: 872.0000 - FN: 365.0000 - TN: 48.0000 - NPV: 0.1162 - specificity: 0.0522 - recall: 0.9555 - auc: 0.5447 - val_loss: 0.5043 - val_TP: 2048.0000 - val_FP: 233.0000 - val_FN: 0.0000e+00 - val_TN: 0.0000e+00 - val_NPV: 0.0000e+00 - val_specificity: 0.0000e+00 - val_recall: 1.0000 - val_auc: 0.5271
# Epoch 2/30
# 92/92 [==============================] - 1s 14ms/step - loss: 0.3507 - TP: 8137.0000 - FP: 895.0000 - FN: 63.0000 - TN: 25.0000 - NPV: 0.2841 - specificity: 0.0272 - recall: 0.9923 - auc: 0.5828 - val_loss: 0.3509 - val_TP: 2048.0000 - val_FP: 233.0000 - val_FN: 0.0000e+00 - val_TN: 0.0000e+00 - val_NPV: 0.0000e+00 - val_specificity: 0.0000e+00 - val_recall: 1.0000 - val_auc: 0.5625
# Epoch 3/30
# 92/92 [==============================] - 1s 14ms/step - loss: 0.3461 - TP: 8157.0000 - FP: 908.0000 - FN: 43.0000 - TN: 12.0000 - NPV: 0.2182 - specificity: 0.0130 - recall: 0.9948 - auc: 0.5852 - val_loss: 0.3265 - val_TP: 2048.0000 - val_FP: 233.0000 - val_FN: 0.0000e+00 - val_TN: 0.0000e+00 - val_NPV: 0.0000e+00 - val_specificity: 0.0000e+00 - val_recall: 1.0000 - val_auc: 0.6151
# Epoch 4/30
# 92/92 [==============================] - 1s 14ms/step - loss: 0.3304 - TP: 8180.0000 - FP: 906.0000 - FN: 20.0000 - TN: 14.0000 - NPV: 0.4118 - specificity: 0.0152 - recall: 0.9976 - auc: 0.6248 - val_loss: 0.3310 - val_TP: 2047.0000 - val_FP: 232.0000 - val_FN: 1.0000 - val_TN: 1.0000 - val_NPV: 0.5000 - val_specificity: 0.0043 - val_recall: 0.9995 - val_auc: 0.6052
# Epoch 5/30
# 92/92 [==============================] - 1s 14ms/step - loss: 0.3215 - TP: 8185.0000 - FP: 905.0000 - FN: 15.0000 - TN: 15.0000 - NPV: 0.5000 - specificity: 0.0163 - recall: 0.9982 - auc: 0.6441 - val_loss: 0.3251 - val_TP: 2048.0000 - val_FP: 231.0000 - val_FN: 0.0000e+00 - val_TN: 2.0000 - val_NPV: 1.0000 - val_specificity: 0.0086 - val_recall: 1.0000 - val_auc: 0.6274
# Epoch 6/30
# 92/92 [==============================] - 1s 14ms/step - loss: 0.3200 - TP: 8191.0000 - FP: 909.0000 - FN: 9.0000 - TN: 11.0000 - NPV: 0.5500 - specificity: 0.0120 - recall: 0.9989 - auc: 0.6479 - val_loss: 0.3250 - val_TP: 2048.0000 - val_FP: 233.0000 - val_FN: 0.0000e+00 - val_TN: 0.0000e+00 - val_NPV: 0.0000e+00 - val_specificity: 0.0000e+00 - val_recall: 1.0000 - val_auc: 0.6178
# Epoch 7/30
# 92/92 [==============================] - 1s 14ms/step - loss: 0.3117 - TP: 8186.0000 - FP: 900.0000 - FN: 14.0000 - TN: 20.0000 - NPV: 0.5882 - specificity: 0.0217 - recall: 0.9983 - auc: 0.6684 - val_loss: 0.3153 - val_TP: 2046.0000 - val_FP: 227.0000 - val_FN: 2.0000 - val_TN: 6.0000 - val_NPV: 0.7500 - val_specificity: 0.0258 - val_recall: 0.9990 - val_auc: 0.6457
# Epoch 8/30
# 92/92 [==============================] - 1s 14ms/step - loss: 0.3043 - TP: 8187.0000 - FP: 880.0000 - FN: 13.0000 - TN: 40.0000 - NPV: 0.7547 - specificity: 0.0435 - recall: 0.9984 - auc: 0.6900 - val_loss: 0.3279 - val_TP: 2047.0000 - val_FP: 228.0000 - val_FN: 1.0000 - val_TN: 5.0000 - val_NPV: 0.8333 - val_specificity: 0.0215 - val_recall: 0.9995 - val_auc: 0.6191
# Epoch 9/30
# 92/92 [==============================] - 1s 14ms/step - loss: 0.3018 - TP: 8177.0000 - FP: 883.0000 - FN: 23.0000 - TN: 37.0000 - NPV: 0.6167 - specificity: 0.0402 - recall: 0.9972 - auc: 0.7001 - val_loss: 0.3110 - val_TP: 2045.0000 - val_FP: 227.0000 - val_FN: 3.0000 - val_TN: 6.0000 - val_NPV: 0.6667 - val_specificity: 0.0258 - val_recall: 0.9985 - val_auc: 0.6579
# Epoch 10/30
# 92/92 [==============================] - 1s 15ms/step - loss: 0.2959 - TP: 8179.0000 - FP: 879.0000 - FN: 21.0000 - TN: 41.0000 - NPV: 0.6613 - specificity: 0.0446 - recall: 0.9974 - auc: 0.7184 - val_loss: 0.3118 - val_TP: 2045.0000 - val_FP: 221.0000 - val_FN: 3.0000 - val_TN: 12.0000 - val_NPV: 0.8000 - val_specificity: 0.0515 - val_recall: 0.9985 - val_auc: 0.6600
# Epoch 11/30
# 92/92 [==============================] - 1s 14ms/step - loss: 0.2964 - TP: 8182.0000 - FP: 870.0000 - FN: 18.0000 - TN: 50.0000 - NPV: 0.7353 - specificity: 0.0543 - recall: 0.9978 - auc: 0.7138 - val_loss: 0.3067 - val_TP: 2045.0000 - val_FP: 222.0000 - val_FN: 3.0000 - val_TN: 11.0000 - val_NPV: 0.7857 - val_specificity: 0.0472 - val_recall: 0.9985 - val_auc: 0.6765
# Epoch 12/30
# 92/92 [==============================] - 1s 14ms/step - loss: 0.2887 - TP: 8178.0000 - FP: 865.0000 - FN: 22.0000 - TN: 55.0000 - NPV: 0.7143 - specificity: 0.0598 - recall: 0.9973 - auc: 0.7365 - val_loss: 0.3232 - val_TP: 2036.0000 - val_FP: 213.0000 - val_FN: 12.0000 - val_TN: 20.0000 - val_NPV: 0.6250 - val_specificity: 0.0858 - val_recall: 0.9941 - val_auc: 0.6677
# Epoch 13/30
# 92/92 [==============================] - 1s 14ms/step - loss: 0.2846 - TP: 8168.0000 - FP: 850.0000 - FN: 32.0000 - TN: 70.0000 - NPV: 0.6863 - specificity: 0.0761 - recall: 0.9961 - auc: 0.7479 - val_loss: 0.3125 - val_TP: 2045.0000 - val_FP: 219.0000 - val_FN: 3.0000 - val_TN: 14.0000 - val_NPV: 0.8235 - val_specificity: 0.0601 - val_recall: 0.9985 - val_auc: 0.6528
# Epoch 14/30
# 92/92 [==============================] - 1s 14ms/step - loss: 0.2858 - TP: 8173.0000 - FP: 836.0000 - FN: 27.0000 - TN: 84.0000 - NPV: 0.7568 - specificity: 0.0913 - recall: 0.9967 - auc: 0.7379 - val_loss: 0.3381 - val_TP: 2046.0000 - val_FP: 225.0000 - val_FN: 2.0000 - val_TN: 8.0000 - val_NPV: 0.8000 - val_specificity: 0.0343 - val_recall: 0.9990 - val_auc: 0.6493
# Epoch 15/30
# 92/92 [==============================] - 1s 14ms/step - loss: 0.2829 - TP: 8168.0000 - FP: 836.0000 - FN: 32.0000 - TN: 84.0000 - NPV: 0.7241 - specificity: 0.0913 - recall: 0.9961 - auc: 0.7483 - val_loss: 0.3125 - val_TP: 2041.0000 - val_FP: 212.0000 - val_FN: 7.0000 - val_TN: 21.0000 - val_NPV: 0.7500 - val_specificity: 0.0901 - val_recall: 0.9966 - val_auc: 0.6668
# Epoch 16/30
# 92/92 [==============================] - 1s 14ms/step - loss: 0.2826 - TP: 8156.0000 - FP: 830.0000 - FN: 44.0000 - TN: 90.0000 - NPV: 0.6716 - specificity: 0.0978 - recall: 0.9946 - auc: 0.7518 - val_loss: 0.3255 - val_TP: 2043.0000 - val_FP: 221.0000 - val_FN: 5.0000 - val_TN: 12.0000 - val_NPV: 0.7059 - val_specificity: 0.0515 - val_recall: 0.9976 - val_auc: 0.6282
# Epoch 17/30
# 92/92 [==============================] - 1s 14ms/step - loss: 0.2747 - TP: 8171.0000 - FP: 824.0000 - FN: 29.0000 - TN: 96.0000 - NPV: 0.7680 - specificity: 0.1043 - recall: 0.9965 - auc: 0.7707 - val_loss: 0.3155 - val_TP: 2042.0000 - val_FP: 222.0000 - val_FN: 6.0000 - val_TN: 11.0000 - val_NPV: 0.6471 - val_specificity: 0.0472 - val_recall: 0.9971 - val_auc: 0.6575
# Epoch 18/30
# 92/92 [==============================] - 1s 14ms/step - loss: 0.2694 - TP: 8156.0000 - FP: 811.0000 - FN: 44.0000 - TN: 109.0000 - NPV: 0.7124 - specificity: 0.1185 - recall: 0.9946 - auc: 0.7888 - val_loss: 0.3122 - val_TP: 2035.0000 - val_FP: 204.0000 - val_FN: 13.0000 - val_TN: 29.0000 - val_NPV: 0.6905 - val_specificity: 0.1245 - val_recall: 0.9937 - val_auc: 0.6704
# Epoch 19/30
# 92/92 [==============================] - 1s 14ms/step - loss: 0.2669 - TP: 8156.0000 - FP: 803.0000 - FN: 44.0000 - TN: 117.0000 - NPV: 0.7267 - specificity: 0.1272 - recall: 0.9946 - auc: 0.7878 - val_loss: 0.3142 - val_TP: 2036.0000 - val_FP: 210.0000 - val_FN: 12.0000 - val_TN: 23.0000 - val_NPV: 0.6571 - val_specificity: 0.0987 - val_recall: 0.9941 - val_auc: 0.6699
# Epoch 20/30
# 92/92 [==============================] - 1s 14ms/step - loss: 0.2607 - TP: 8148.0000 - FP: 776.0000 - FN: 52.0000 - TN: 144.0000 - NPV: 0.7347 - specificity: 0.1565 - recall: 0.9937 - auc: 0.8002 - val_loss: 0.3309 - val_TP: 2011.0000 - val_FP: 203.0000 - val_FN: 37.0000 - val_TN: 30.0000 - val_NPV: 0.4478 - val_specificity: 0.1288 - val_recall: 0.9819 - val_auc: 0.6556
# Epoch 21/30
# 92/92 [==============================] - 1s 14ms/step - loss: 0.2604 - TP: 8163.0000 - FP: 795.0000 - FN: 37.0000 - TN: 125.0000 - NPV: 0.7716 - specificity: 0.1359 - recall: 0.9955 - auc: 0.8049 - val_loss: 0.3300 - val_TP: 2023.0000 - val_FP: 200.0000 - val_FN: 25.0000 - val_TN: 33.0000 - val_NPV: 0.5690 - val_specificity: 0.1416 - val_recall: 0.9878 - val_auc: 0.6498

# %%
#Only run this cell if you want to reload model run previously.
model_folder = '/content/drive/My Drive/Colab Notebooks/models/'

custom_objects = {"NPV": NPV, "Specificity": Specificity}
with keras.utils.custom_object_scope(custom_objects):
    model = tf.keras.models.load_model(model_folder + "Covid_Model_m1.h5")

# %% [markdown]
# # **Apply model to test dataset.**

# %%
_,TP,FP,FN,TN, Spec, npv, Recall, AUC = model.evaluate(test_dataset)
print('Confusion Matrix: ', TP, FP, FN, TN)
print('Test NPV: %.4f' % npv)
print('Test Specificity: %.4f' % Spec)
print('Test Sensitivity: %.4f' % Recall)
print('Test ROC-AUC: %.4f' % AUC)
# Out:
# 10/10 [==============================] - 0s 8ms/step - loss: 0.3446 - TP: 885.0000 - FP: 113.0000 - FN: 1.0000 - TN: 1.0000 - NPV: 0.5000 - specificity: 0.0088 - recall: 0.9989 - auc: 0.6496
# Confusion Matrix:  885.0 113.0 1.0 1.0
# Test NPV: 0.0088
# Test Specificity: 0.5000
# Test Sensitivity: 0.9989
# Test ROC-AUC: 0.6496
